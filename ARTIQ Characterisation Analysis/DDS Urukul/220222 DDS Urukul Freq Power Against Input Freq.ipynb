# %% [markdown]
# # 220704 Replot the Frequency Response Plots as .pdf vector format
#
# #### Change to .pdf vector format
# #### Change font size

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import time as time
plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['xtick.major.size'] = 5.0
plt.rcParams['xtick.minor.size'] = 3.0
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['legend.handlelength'] = 1.0

# %% [markdown]
# 1

# %%
df = pd.read_excel('220222 DDS Urukul Freq Power Against Input Freq.xlsx')
x = df.iloc[:13,0]
y = df.iloc[:13,1]
plt.figure(figsize=(7.5,6))
plt.plot(x,y,'x',markersize=10)
plt.plot(x,x)
plt.xlabel('Set frequency / MHz')
plt.ylabel('Measured frequency / MHz')
plt.title('Urukul measured frequency against input frequency')
plt.savefig('urukul_freq_against_freq'+'.pdf',bbox_inches='tight',dpi=300)

# %% [markdown]
# 2

# %%
df = pd.read_excel('220222 DDS Urukul Freq Power Against Input Freq.xlsx')
x = df.iloc[:13,0]
y = df.iloc[:13,4]
plt.figure(figsize=(7.5,6))
plt.plot(x,y,'x',markersize=10)
plt.xlabel('Set frequency / MHz')
plt.ylabel('Measured power / dBm')
plt.title('Urukul measured RF Power against input frequency')
plt.savefig('urukul_power_against_freq'+'.pdf',bbox_inches='tight',dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['xtick.major.size'] = 5.0
plt.rcParams['xtick.minor.size'] = 3.0
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['legend.handlelength'] = 1.0

# %%
import pandas as pd

# %%
df = pd.read_excel('220222 DDS Urukul Freq Power Against Input Freq.xlsx')

# %%
df
# Out:
#     Set frequency (MHz)  Measured frequency (MHz)  Set Amplitude (arb)  \
# 0                    50                    50.002                    1
# 1                   100                    100.01                    1
# 2                   150                   150.005                    1
# 3                   200                   199.994                    1
# 4                   250                    249.99                    1
# 5                   300                     299.7                    1
# 6                   350                       350                    1
# 7                   400                   400.004                    1
# 8                   450                   449.997                    1
# 9                     1                         1                    1
# 10                    5                     5.003                    1
# 11                   10                     9.994                    1
# ...

# %%
x = df.iloc[0:9,0]
y = df.iloc[0:9,4]
plt.figure(figsize=(10,8))
plt.plot(x,y,'x',markersize=10)
plt.xlabel('Set frequency / MHz')
plt.ylabel('Measured power / dBm')
plt.title('Urukul measured RF Power as a function of set frequency')
# Out:
# Text(0.5, 1.0, 'Urukul measured RF Power as a function of set frequency')

# %%
x = df.iloc[9:,0]
y = df.iloc[9:,4]
plt.figure(figsize=(10,8))
plt.plot(x,y,'x',markersize=10)
plt.xlabel('Set frequency / MHz')
plt.ylabel('Measured power / dBm')
plt.title('Urukul measured RF Power as a function of set frequency')
# Out:
# Text(0.5, 1.0, 'Urukul measured RF Power as a function of set frequency')

# %%
x = df.iloc[:,0]
y = df.iloc[:,4]
plt.figure(figsize=(10,8))
plt.plot(x,y,'x',markersize=10)
plt.xlabel('Set frequency / MHz')
plt.ylabel('Measured power / dBm')
plt.title('Urukul measured RF Power as a function of set frequency')
# Out:
# Text(0.5, 1.0, 'Urukul measured RF Power as a function of set frequency')

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]
plt.figure(figsize=(10,8))
plt.plot(x,y,'x',markersize=10)
plt.plot(x,x)
plt.xlabel('Set frequency / MHz')
plt.ylabel('Measured frequency / MHz')
plt.title('Urukul measured frequency as a function of set frequency')
# Out:
# Text(0.5, 1.0, 'Urukul measured frequency as a function of set frequency')
