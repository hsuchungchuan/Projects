# %%
# import stuff

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# # import tex fonts for nice graphs :)

# plt.rcParams['text.usetex'] = True
# plt.rcParams['font.size'] = 18
# plt.rcParams['legend.fontsize'] = 12
# plt.rcParams['xtick.direction'] = 'out'
# plt.rcParams['ytick.direction'] = 'out'
# plt.rcParams['xtick.major.size'] = 5.0
# plt.rcParams['xtick.minor.size'] = 3.0
# plt.rcParams['ytick.major.size'] = 5.0
# plt.rcParams['ytick.minor.size'] = 3.0
# plt.rcParams['legend.handlelength'] = 1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read the xlsx file into a pandas DataFrame
df = pd.read_excel('ShelvingIntensity_vs_Detuning_Data.xlsx')

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1       Unnamed: 2      Unnamed: 3  \
# 0          NaN         NaN  Frequency / THz  Detuning / MHz
# 1          NaN         NaN       434.829245               0
# 2          NaN         NaN       434.829251             6.0
# 3          NaN         NaN       434.829225           -20.0
# 4          NaN         NaN        434.82923           -15.0
# 5          NaN         NaN       434.829235           -10.0
# 6          NaN         NaN        434.82924            -5.0
# 7          NaN         NaN       434.829255            10.0
# 8          NaN         NaN        434.82926            15.0
# 9          NaN         NaN       434.829265            20.0
# 10         NaN         NaN        434.82927            25.0
# 11         NaN         NaN       434.829275            30.0
# 12         NaN         NaN        434.82928            35.0
# 13         NaN         NaN        434.82922           -25.0
#
#                                           Unnamed: 4  \
# 0   Shelving Peak Signal normalised to av MOT signal
# 1                                            0.43096
# 2                                           0.303748
# 3                                           0.139196
# 4                                           0.199356
# 5                                           0.272202
# 6                                            0.19849
# 7                                           0.247427
# 8                                           0.277944
# 9                                           0.229673
# 10                                          0.164805
# 11                                                 0
# 12                                                 0
# 13                                                 0
#
#                                            Unnamed: 5  \
# 0   Shelving Peak Signal std dev normalised to av ...
# 1                                            0.016097
# 2                                            0.019471
# 3                                            0.015823
# 4                                            0.011726
# 5                                            0.014558
# 6                                            0.032273
# 7                                            0.035537
# 8                                            0.020477
# 9                                            0.007983
# 10                                           0.032306
# 11                                                  0
# 12                                                  0
# 13                                                  0
#
#                                          Unnamed: 6  \
# 0   Shelving Dip Signal normalised to av MOT signal
# 1                                          0.308897
# 2                                          0.241632
# 3                                          0.134892
# 4                                          0.186874
# 5                                          0.225597
# 6                                          0.183438
# 7                                          0.207719
# 8                                          0.236462
# 9                                          0.204142
# 10                                         0.157821
# 11                                                0
# 12                                                0
# 13                                                0
#
#                                            Unnamed: 7  \
# 0   Shelving Dip Signal std dev normalised to av M...
# 1                                            0.020855
# 2                                            0.011028
# 3                                            0.017478
# 4                                            0.016604
# 5                                            0.012184
# 6                                            0.014897
# 7                                            0.009724
# 8                                            0.010256
# 9                                            0.019003
# 10                                           0.021176
# 11                                                  0
# 12                                                  0
# 13                                                  0
#
#                      Unnamed: 8
# 0   Freq Detuning err bar / MHz
# 1                           0.5
# 2                           0.5
# 3                           0.5
# 4                           0.5
# 5                           0.5
# 6                           0.5
# 7                           0.5
# 8                           0.5
# 9                           0.5
# 10                          0.5
# 11                          0.5
# 12                          0.5
# 13                          0.5

# %%
plt.figure(figsize=(10,6))
#include error bars in y using the std dev column
plt.errorbar(df.iloc[1:,3], df.iloc[1:,4], yerr=df.iloc[1:,5], xerr=df.iloc[1:,8], fmt='o', capsize=3, capthick=1)
plt.xticks(np.arange(-25, 36, 5))
plt.title('Normalised Shelving Peak Intensity vs Frequency Detuning')
plt.xlabel('Frequency Detuning (MHz)')
plt.ylabel('Normalised Shelving Peak Intensity')
plt.grid()
# plt.savefig('ShelvingPeakIntensity_vs_Detuning.png',dpi=300)
# plt.savefig('ShelvingPeakIntensity_vs_Detuning.pdf',dpi=300)

# %%
plt.figure(figsize=(10,6))
#include error bars in y using the std dev column
plt.errorbar(df.iloc[1:,3], df.iloc[1:,6], yerr=df.iloc[1:,7], xerr=df.iloc[1:,8], fmt='o', capsize=3, capthick=1)
plt.xticks(np.arange(-25, 36, 5))
plt.title('Normalised Shelving Dip Intensity vs Frequency Detuning')
plt.xlabel('Frequency Detuning (MHz)')
plt.ylabel('Normalised Shelving Dip Intensity')
plt.grid()
# plt.savefig('ShelvingDipIntensity_vs_Detuning.png',dpi=300)
# plt.savefig('ShelvingDipIntensity_vs_Detuning.pdf',dpi=300)

# %%
# Find the average of column 4 and column 6 i.e. the peaks and dips

df['Average'] = (df.iloc[1:,4] + df.iloc[1:,6])/2
df['AverageError'] = (df.iloc[1:,5] + df.iloc[1:,7])/2

plt.figure(figsize=(10,6))
#include error bars in y using the std dev column
plt.errorbar(df.iloc[1:,3], df.iloc[1:,9], yerr=df.iloc[1:,10], xerr=df.iloc[1:,8], fmt='o', capsize=3, capthick=1)
plt.xticks(np.arange(-25, 36, 5))
plt.title('Normalised Shelving Average Intensity vs Frequency Detuning')
plt.xlabel('Frequency Detuning (MHz)')
plt.ylabel('Normalised Shelving Average Intensity')
plt.grid()
# plt.savefig('ShelvingAverageIntensity_vs_Detuning.png',dpi=300)
# plt.savefig('ShelvingAverageIntensity_vs_Detuning.pdf',dpi=300)

# %%
## On your .ipynb, import this plotting_style by adding in and uncommenting the following lines:

import matplotlib.pyplot as plt
import sys
sys.path.append('C:/Users/Michael/Dropbox/AION/Projects')  # Replace with the relevant path that contains this script
from plotting_style import set_plotting_style
set_plotting_style()
# Out:
# Initialising plotting style...
# Success! Plotting style initialised.

# %%
# Plot all three on the same graph

# plt.figure(figsize=(10,6))
#include error bars in y using the std dev column
plt.errorbar(df.iloc[1:,3], df.iloc[1:,4], yerr=df.iloc[1:,5], xerr=df.iloc[1:,8], fmt='o', markersize=5, capsize=3, capthick=1, label='Peak')
plt.errorbar(df.iloc[1:,3], df.iloc[1:,6], yerr=df.iloc[1:,7], xerr=df.iloc[1:,8], fmt='o', markersize=5, capsize=3, capthick=1, label='Dip')
plt.errorbar(df.iloc[1:,3], df.iloc[1:,9], yerr=df.iloc[1:,10], xerr=df.iloc[1:,8], fmt='o', markersize=5, capsize=3, capthick=1, label='Average')
plt.xticks(np.arange(-30, 31, 10))
plt.yticks(np.arange(0, 0.7, 0.1))
# plt.title('Normalised Shelving Intensity vs Frequency Detuning')
plt.xlabel('Frequency Detuning (MHz)')
plt.ylabel('Normalised Shelving Intensity')
# plt.grid()
plt.legend()
plt.savefig('Poster_TVLBAI_ShelvingIntensity_vs_Detuning_All.png',dpi=300, bbox_inches='tight')
plt.savefig('Poster_TVLBAI_ShelvingIntensity_vs_Detuning_All.pdf',dpi=300, bbox_inches='tight')

# %%
# Plot all three on the same graph

# plt.figure(figsize=(10,6))
#include error bars in y using the std dev column
plt.errorbar(df.iloc[1:,3], df.iloc[1:,4], yerr=df.iloc[1:,5], xerr=df.iloc[1:,8], fmt='o', capsize=3, capthick=1, label='Peak')
plt.errorbar(df.iloc[1:,3], df.iloc[1:,6], yerr=df.iloc[1:,7], xerr=df.iloc[1:,8], fmt='o', capsize=3, capthick=1, label='Dip')
plt.errorbar(df.iloc[1:,3], df.iloc[1:,9], yerr=df.iloc[1:,10], xerr=df.iloc[1:,8], fmt='o', capsize=3, capthick=1, label='Average')
plt.xticks(np.arange(-25, 36, 5))
plt.title('Normalised Shelving Intensity vs Frequency Detuning')
plt.xlabel('Frequency Detuning (MHz)')
plt.ylabel('Normalised Shelving Intensity')
plt.grid()
plt.legend()
plt.savefig('ShelvingIntensity_vs_Detuning_All.png',dpi=300)
plt.savefig('ShelvingIntensity_vs_Detuning_All.pdf',dpi=300)
