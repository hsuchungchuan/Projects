# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib nbagg
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import time as time

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = 18
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['xtick.major.size'] = 5.0
plt.rcParams['xtick.minor.size'] = 3.0
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['legend.handlelength'] = 1.0

# %% [markdown]
# # scope_0: 10ms

# %%
df = pd.read_csv('scope_0_PDHon_10ms.csv',header=1) # scope_14

#zoom in
df;

plt.figure(figsize=(9,6))
plt.plot(df['second'],df['Volt'],label='Fast Out')
plt.plot(df['second'],df['Volt.1'],label='Transmission (Fast PD)')
plt.plot(df['second'],df['Volt.2'],label='Error Signal (Monitoring Output)')
plt.plot(df['second'],df['Volt.3'],label='Slow Out')

plt.legend()
plt.title('221109 Oscilloscope Signal, engaged PDH lock, 10ms resolution')
plt.axhline(0,color='black',ls='--')
plt.xlabel('Time / s')
plt.ylabel('Voltage / V')
plt.savefig('221109 Oscilloscope Signal, engaged PDH lock, 10ms resolution.pdf',bbox_inches='tight',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # scope_1: 1ms

# %%
df = pd.read_csv('scope_1_PDHon_1ms.csv',header=1) # scope_14

#zoom in
df;

plt.figure(figsize=(9,6))
plt.plot(df['second'],df['Volt'],label='Fast Out')
plt.plot(df['second'],df['Volt.1'],label='Transmission (Fast PD)')
plt.plot(df['second'],df['Volt.2'],label='Error Signal (Monitoring Output)')
plt.plot(df['second'],df['Volt.3'],label='Slow Out')

plt.legend()
plt.title('221109 Oscilloscope Signal, engaged PDH lock, 1ms resolution')
plt.axhline(0,color='black',ls='--')
plt.xlabel('Time / s')
plt.ylabel('Voltage / V')
plt.savefig('221109 Oscilloscope Signal, engaged PDH lock, 1ms resolution.pdf',bbox_inches='tight',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # scope_2: 10us

# %%
df = pd.read_csv('scope_2_PDHon_10us.csv',header=1) # scope_14

#zoom in
df;

plt.figure(figsize=(9,6))
plt.plot(df['second'],df['Volt'],label='Fast Out')
plt.plot(df['second'],df['Volt.1'],label='Transmission (Fast PD)')
plt.plot(df['second'],df['Volt.2'],label='Error Signal (Monitoring Output)')
plt.plot(df['second'],df['Volt.3'],label='Slow Out')

plt.legend()
plt.title(r'221109 Oscilloscope Signal, engaged PDH lock, 10$\mu$s resolution')
plt.axhline(0,color='black',ls='--')
plt.xlabel('Time / s')
plt.ylabel('Voltage / V')
plt.savefig('221109 Oscilloscope Signal, engaged PDH lock, 10us resolution.pdf',bbox_inches='tight',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # scope_3: 2us

# %%
df = pd.read_csv('scope_3_PDHon_2us.csv',header=1) # scope_14

#zoom in
df;

plt.figure(figsize=(9,6))
plt.plot(df['second']*1e3,df['Volt'],label='Fast Out')
plt.plot(df['second']*1e3,df['Volt.1'],label='Transmission (Fast PD)')
plt.plot(df['second']*1e3,df['Volt.2'],label='Error Signal (Monitoring Output)')
plt.plot(df['second']*1e3,df['Volt.3'],label='Slow Out')
plt.legend()
plt.title(r'221109 Oscilloscope Signal, engaged PDH lock, 2$\mu$s resolution')
plt.axhline(0,color='black',ls='--')
plt.xlabel('Time / ms')
plt.ylabel('Voltage / V')
plt.savefig('221109 Oscilloscope Signal, engaged PDH lock, 2us resolution.pdf',bbox_inches='tight',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Further zoom in of above (scope_3)

# %%
df = pd.read_csv('scope_3_PDHon_2us.csv',header=1) # scope_14

#zoom in
df = df[11405:11671] #0.004861402s to 0.004861668

plt.figure(figsize=(9,6))
plt.plot(df['second']*1e6,df['Volt'],label='Fast Out')
plt.plot(df['second']*1e6,df['Volt.1'],label='Transmission (Fast PD)')
plt.plot(df['second']*1e6,df['Volt.2'],label='Error Signal (Monitoring Output)')
plt.plot(df['second']*1e6,df['Volt.3'],label='Slow Out')

plt.legend()
plt.title(r'221109 Oscilloscope Signal, engaged PDH lock, 2$\mu$s resolution')
plt.axhline(0,color='black',ls='--')
plt.xlabel(r'Time / $\mu$s')
plt.ylabel('Voltage / V')
plt.savefig('221109 Oscilloscope Signal, engaged PDH lock, 2us resolution, zoom in more.pdf',bbox_inches='tight',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Scope 4

# %%
df = pd.read_csv('MountainTopSustainedTransmissionPeak/scope_4_RightBeforePDHLock_TransmissionPeakSustained_MountainTop.csv',header=1) # scope_14

#zoom in
# df = df[11405:11671] #0.004861402s to 0.004861668

df.iloc[:,1] = df.iloc[:,1]+3.4 #translate fast out up by 4.4V to centralise on zero for better visuals
df.iloc[:,0] = df.iloc[:,0]+0.001 #translate fast out up by 4.4V to centralise on zero for better visuals

plt.figure(figsize=(9,6))
plt.plot(df['second'],df['Volt']/10,label='Fast Out',alpha=0.5)
plt.plot(df['second'],df['Volt.1'],label='Transmission Signal')
plt.plot(df['second'],df['Volt.2'],label='Error Signal')
plt.plot(df['second'],df['Volt.3'],label='Slow Out')

plt.legend()
plt.title(r'221109 Oscilloscope trace near lock')
plt.axhline(0,color='black',ls='--')
plt.xlabel(r'Time / s')
plt.ylabel('Voltage / V')
plt.savefig('221109 Oscilloscope Signal near lock.pdf',bbox_inches='tight',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="900">
