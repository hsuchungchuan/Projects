# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# copy paste this code to the beginning of your script to set the plotting style for a one column figure

from matplotlib import pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "figure.constrained_layout.use": True
})

plt.rcParams["savefig.bbox"] = None
plt.rcParams["figure.figsize"] = (5.9,3.5)  # (width, height) in inches, change height but not width
plt.rcParams["figure.titlesize"] = 10 # this is only for plt.suptitle, i set it to be the same as the rest

plt.rcParams["axes.titlesize"] = 10 # control title size
plt.rcParams["axes.labelsize"] = 10 # control x and y axis labels
plt.rcParams["axes.labelpad"] = 4.0 # distance between axis label and axis numbers
plt.rcParams["xtick.labelsize"] = 10 # independent control of xlabel fontsize
plt.rcParams["ytick.labelsize"] = 10 # independent control of ylabel fontsize

plt.rcParams["legend.fontsize"] = 7.5 # control legend size, I set it to be slightly smaller than title/axes label
# plt.rcParams["legend.facecolor"] = (0.9, 0.9, 0.9) # legend background color
# plt.rcParams["legend.edgecolor"] = (0, 0, 0) # legend border line color
# plt.rcParams["legend.frameon"] = True # whether or not to draw a border around legend
# plt.rcParams["legend.framealpha"] = 0.1 # legend background transparency
plt.rcParams["legend.loc"] = "best" # default legend location
plt.rcParams["legend.handletextpad"] = 0.8  # Horizontal space between legend point and text (default 0.8)
plt.rcParams["legend.labelspacing"] = 0.6  # Vertical space between legend entries (default 0.5)
# plt.rcParams["legend.columnspacing"] = 2.0  # Space between columns in multi-column legends
# plt.rcParams["legend.borderpad"] = 1.0  # Space between legend content and the box
# plt.rcParams["legend.handlelength"] = 2.0  # Length of legend marker lines

plt.rcParams["lines.linewidth"] = 1
plt.rcParams["lines.markersize"] = 6 #data point size

# CHOOSE NICE COLOR FOR DARK MARKER EDGEWIDTH FROM "dodgerblue","mediumseagreen","crimson","mediumpurple","slateblue","darkorange","peru","goldenrod"
plt.rcParams["lines.linewidth"] = 1
plt.rcParams["lines.markersize"] = 6 #data point size
plt.rcParams["lines.markeredgewidth"] = 1.5 # width of the edge of the marker
plt.rcParams["lines.markeredgecolor"] = "black" # color of the edge of the marker
plt.rcParams["lines.markerfacecolor"] = "crimson" # color of the inside of the marker
plt.rcParams["lines.marker"] = "o" # marker type, see https://matplotlib.org/stable/api/markers_api.html for all options
plt.rcParams["lines.color"] = "black" # color of the line
# # CHOOSE NICE COLOR FOR DARK MARKER EDGEWIDTH FROM "dodgerblue","mediumseagreen","crimson","mediumpurple","slateblue","darkorange","peru","goldenrod"


# plt.rcParams["grid.linestyle"] = "--"
# plt.rcParams['axes.grid'] = True
# plt.rcParams["grid.linewidth"] = 0.7

# plt.rcParams["xtick.major.pad"] = 4.0 # distance between xticks dashes and xaxis numbers
# plt.rcParams["xtick.major.size"] = 3.0
# plt.rcParams["xtick.major.width"] = 0.7
# plt.rcParams["ytick.major.pad"] = 4.0 # distance between yticks dashes and yaxis numbers
# plt.rcParams["ytick.major.size"] = 3.0
# plt.rcParams["ytick.major.width"] = 0.7

# %%
# I want the plot to not have a box and only show the x and y axes
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# I want the y-axis to be when x-axis is 1055
plt.gca().spines['left'].set_position(('data', 1055))
plt.gca().spines['bottom'].set_position(('data', 0))


# I want to write "resonance" above the y-axis
plt.text(1055, 1.15, "Resonance", va='center', ha='center')

# Set the range of x-axis from 1050 to 1066
plt.xlim(1050, 1070)
# Set the range of y-axis from 0 to 1
plt.ylim(0, 1.1)
# Set the ticks on the x-axis to be from 1050 to 1070 with a step of 1
plt.xticks(np.arange(1050, 1071, 1),rotation=90)

# I don't want to show the ticks on the y-axis
plt.yticks([])

plt.xlabel(r"$f_{cavityoffset}$ (MHz)", labelpad=5.0)

x_errorbar = 5
plt.errorbar(1056,0.1,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.09, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1057,0.2,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.19, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1058,0.3,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.29, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1059,0.4,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.39, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1060,0.5,xerr=x_errorbar-0.1,color='black',capsize=5,markerfacecolor="white")
plt.text(1048, 0.49, "No red MOT", va='center', ha='center', rotation=0)
plt.errorbar(1061,0.6,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.59, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1062,0.7,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.69, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1063,0.8,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.79, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1064,0.9,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.89, "Red MOT (B)", va='center', ha='center', rotation=0)

plt.vlines(x=1060, ymin=0, ymax=0.5, color='black', linewidth=1,linestyle='--')

plt.savefig("250502 BBRedMOT2DScanModWidthFreqSchematicExplanation_5MHzWidth.pdf", dpi=300)

# %%
# I want the plot to not have a box and only show the x and y axes
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# I want the y-axis to be when x-axis is 1055
plt.gca().spines['left'].set_position(('data', 1055))
plt.gca().spines['bottom'].set_position(('data', 0))


# I want to write "resonance" above the y-axis
plt.text(1055, 1.15, "Resonance", va='center', ha='center')

# Set the range of x-axis from 1050 to 1066
plt.xlim(1050, 1070)
# Set the range of y-axis from 0 to 1
plt.ylim(0, 1.1)
# Set the ticks on the x-axis to be from 1050 to 1070 with a step of 1
plt.xticks(np.arange(1050, 1071, 1),rotation=90)

# I don't want to show the ticks on the y-axis
plt.yticks([])

plt.xlabel(r"$f_{cavityoffset}$ (MHz)", labelpad=5.0)

x_errorbar = 6
plt.errorbar(1056,0.1,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.09, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1057,0.2,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.19, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1058,0.3,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.29, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1059,0.4,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.39, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1060,0.5,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.49, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1061,0.6,xerr=x_errorbar-0.1,color='black',capsize=5,markerfacecolor="white")
plt.text(1048, 0.59, "No red MOT", va='center', ha='center', rotation=0)
plt.errorbar(1062,0.7,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.69, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1063,0.8,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.79, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1064,0.9,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.89, "Red MOT (B)", va='center', ha='center', rotation=0)

plt.vlines(x=1061, ymin=0, ymax=0.6, color='black', linewidth=1,linestyle='--')

plt.savefig("250502 BBRedMOT2DScanModWidthFreqSchematicExplanation_6MHzWidth.pdf", dpi=300)

# %%
# I want the plot to not have a box and only show the x and y axes
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# I want the y-axis to be when x-axis is 1055
plt.gca().spines['left'].set_position(('data', 1055))
plt.gca().spines['bottom'].set_position(('data', 0))


# I want to write "resonance" above the y-axis
plt.text(1055, 1.15, "Resonance", va='center', ha='center')

# Set the range of x-axis from 1050 to 1066
plt.xlim(1050, 1070)
# Set the range of y-axis from 0 to 1
plt.ylim(0, 1.1)
# Set the ticks on the x-axis to be from 1050 to 1070 with a step of 1
plt.xticks(np.arange(1050, 1071, 1),rotation=90)

# I don't want to show the ticks on the y-axis
plt.yticks([])

plt.xlabel(r"$f_{cavityoffset}$ (MHz)", labelpad=5.0)

x_errorbar = 4
plt.errorbar(1056,0.1,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.09, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1057,0.2,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.19, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1058,0.3,xerr=x_errorbar,color='black',capsize=5)
plt.text(1048, 0.29, "Red MOT (A)", va='center', ha='center', rotation=0)
plt.errorbar(1059,0.4,xerr=x_errorbar-0.1,color='black',capsize=5,markerfacecolor="white")
plt.text(1048, 0.39, "No red MOT", va='center', ha='center', rotation=0)
plt.errorbar(1060,0.5,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.49, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1061,0.6,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.59, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1062,0.7,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.69, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1063,0.8,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.79, "Red MOT (B)", va='center', ha='center', rotation=0)
plt.errorbar(1064,0.9,xerr=x_errorbar,color='black',capsize=5,markerfacecolor="firebrick")
plt.text(1048, 0.89, "Red MOT (B)", va='center', ha='center', rotation=0)

plt.vlines(x=1059, ymin=0, ymax=0.4, color='black', linewidth=1,linestyle='--')

plt.savefig("250502 BBRedMOT2DScanModWidthFreqSchematicExplanation_4MHzWidth.pdf", dpi=300)

# %%
fig, axs = plt.subplots(3, 1, sharex=True, figsize=(5.9, 7))

# Plot for 6MHz width
axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)
axs[0].spines['left'].set_position(('data', 1055))
axs[0].spines['bottom'].set_position(('data', 0))
# axs[0].text(1055, 1.15, "Resonance", va='center', ha='center')
axs[0].set_xlim(1050, 1070)
axs[0].set_ylim(0, 1.1)
axs[0].set_yticks([])
axs[0].set_xticks(np.arange(1050, 1071, 1))
axs[0].errorbar(1056, 0.1, xerr=6, color='black', capsize=5)
axs[0].text(1048, 0.09, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[0].errorbar(1057, 0.2, xerr=6, color='black', capsize=5)
axs[0].text(1048, 0.19, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[0].errorbar(1058, 0.3, xerr=6, color='black', capsize=5)
axs[0].text(1048, 0.29, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[0].errorbar(1059, 0.4, xerr=6, color='black', capsize=5)
axs[0].text(1048, 0.39, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[0].errorbar(1060, 0.5, xerr=6, color='black', capsize=5)
axs[0].text(1048, 0.49, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[0].errorbar(1061, 0.6, xerr=5.9, color='black', capsize=5, markerfacecolor="white")
axs[0].text(1048, 0.59, "No red MOT", va='center', ha='center', rotation=0)
axs[0].errorbar(1062, 0.7, xerr=6, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[0].text(1048, 0.69, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[0].errorbar(1063, 0.8, xerr=6, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[0].text(1048, 0.79, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[0].errorbar(1064, 0.9, xerr=6, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[0].text(1048, 0.89, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[0].vlines(x=1060, ymin=0, ymax=0.5, color='black', linewidth=1,linestyle='--')
axs[0].text(1064,0.975, r"$\pm$6MHz", va='center', ha='center', rotation=0)

# Plot for 5MHz width
axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
axs[1].spines['left'].set_position(('data', 1055))
axs[1].spines['bottom'].set_position(('data', 0))
# axs[1].text(1055, 1.15, "Resonance", va='center', ha='center')
axs[1].set_xlim(1050, 1070)
axs[1].set_ylim(0, 1.1)
axs[1].set_yticks([])
x_errorbar= 5
axs[1].errorbar(1056, 0.1, xerr=x_errorbar, color='black', capsize=5)
axs[1].text(1048, 0.09, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[1].errorbar(1057, 0.2, xerr=x_errorbar, color='black', capsize=5)
axs[1].text(1048, 0.19, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[1].errorbar(1058, 0.3, xerr=x_errorbar, color='black', capsize=5)
axs[1].text(1048, 0.29, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[1].errorbar(1059, 0.4, xerr=x_errorbar, color='black', capsize=5)
axs[1].text(1048, 0.39, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[1].errorbar(1060, 0.5, xerr=x_errorbar - 0.1, color='black', capsize=5, markerfacecolor="white")
axs[1].text(1048, 0.49, "No red MOT", va='center', ha='center', rotation=0)
axs[1].errorbar(1061, 0.6, xerr=x_errorbar, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[1].text(1048, 0.59, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[1].errorbar(1062, 0.7, xerr=x_errorbar, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[1].text(1048, 0.69, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[1].errorbar(1063, 0.8, xerr=x_errorbar, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[1].text(1048, 0.79, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[1].errorbar(1064, 0.9, xerr=x_errorbar, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[1].text(1048, 0.89, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[1].vlines(x=1059, ymin=0, ymax=0.4, color='black', linewidth=1, linestyle='--')
axs[1].text(1064,0.975, r"$\pm$5MHz", va='center', ha='center', rotation=0)

# Plot for 4MHz width
axs[2].spines['top'].set_visible(False)
axs[2].spines['right'].set_visible(False)
axs[2].spines['left'].set_position(('data', 1055))
axs[2].spines['bottom'].set_position(('data', 0))
# axs[2].text(1055, 1.15, "Resonance", va='center', ha='center')
axs[2].set_xlim(1050, 1070)
axs[2].set_ylim(0, 1.1)
axs[2].set_yticks([])
axs[2].set_xlabel(r"$f_{cavityoffset}$ (MHz)", labelpad=5.0)
axs[2].errorbar(1056, 0.1, xerr=4, color='black', capsize=5)
axs[2].text(1048, 0.09, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[2].errorbar(1057, 0.2, xerr=4, color='black', capsize=5)
axs[2].text(1048, 0.19, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[2].errorbar(1058, 0.3, xerr=4, color='black', capsize=5)
axs[2].text(1048, 0.29, "Red MOT (A)", va='center', ha='center', rotation=0, color="crimson", fontweight='bold')
axs[2].errorbar(1059, 0.4, xerr=3.9, color='black', capsize=5, markerfacecolor="white")
axs[2].text(1048, 0.39, "No red MOT", va='center', ha='center', rotation=0)
axs[2].errorbar(1060, 0.5, xerr=4, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[2].text(1048, 0.49, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[2].errorbar(1061, 0.6, xerr=4, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[2].text(1048, 0.59, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[2].errorbar(1062, 0.7, xerr=4, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[2].text(1048, 0.69, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[2].errorbar(1063, 0.8, xerr=4, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[2].text(1048, 0.79, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[2].errorbar(1064, 0.9, xerr=4, color='black', capsize=5, markerfacecolor="dodgerblue")
axs[2].text(1048, 0.89, "Red MOT (B)", va='center', ha='center', rotation=0, color="dodgerblue", fontweight='bold')
axs[2].vlines(x=1058, ymin=0, ymax=0.3, color='black', linewidth=1, linestyle='--')
axs[2].text(1064,0.975, r"$\pm$4MHz", va='center', ha='center', rotation=0)

axs[0].axvspan(1050, 1055, color='crimson', alpha=0.15)
axs[0].axvspan(1055, 1070, color='dodgerblue', alpha=0.15)
axs[1].axvspan(1050, 1055, color='crimson', alpha=0.15)
axs[1].axvspan(1055, 1070, color='dodgerblue', alpha=0.15)
axs[2].axvspan(1050, 1055, color='crimson', alpha=0.15)
axs[2].axvspan(1055, 1070, color='dodgerblue', alpha=0.15)

axs[0].set_title(r"$\pm$6 MHz Modulation Width")
axs[1].set_title(r"$\pm$5 MHz Modulation Width")
axs[2].set_title(r"$\pm$4 MHz Modulation Width")

# plt.tight_layout()
plt.xticks(np.arange(1050, 1071, 1),rotation=90)
plt.savefig("250502 BBRedMOT2DSCanModWidthFreqSchematicExplanation_Combined_Plot.pdf", dpi=300)
plt.show()
