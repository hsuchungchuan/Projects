# %% [markdown]
# # 220728 AOM Efficiency vs RF power
#
# ## Now can go up to 2W power :D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import time as time
plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['xtick.major.size'] = 5.0
plt.rcParams['xtick.minor.size'] = 3.0
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['legend.handlelength'] = 1.0

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '280722'
row_start = 10
row_end = 19

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

df = df.sort_values('rf power / W')

rf_inputpower = df.iloc[:,4]
efficiency2 = df.iloc[:,6]

plt.figure(figsize=(7.5,6))
plt.plot(rf_inputpower,efficiency2,'o--')
plt.xlabel('RF Power / W')
plt.ylabel(r'Diffraction Efficiency / $\%$')
plt.title('Efficiency of 1st-order diffraction from AOM as a function of RF power')
# plt.show()
plt.savefig('220728 aom efficiency vs rf power'+'.png',bbox_inches='tight',dpi=300)

# %% [markdown]
# # 220704 Replot the Frequency Response Plots as .pdf vector format
#
# #### Change to .pdf vector format
# #### Change font size

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import time as time
plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = 18
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['xtick.major.size'] = 5.0
plt.rcParams['xtick.minor.size'] = 3.0
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['legend.handlelength'] = 1.0

# %% [markdown]
# 1

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '150622'
row_start = 8
row_end = 22

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

df = df.sort_values('RF frequency / MHz')

rf_freq = df.iloc[:,1]
efficiency = df.iloc[:,3] * 100

plt.figure(figsize=(9,6))
plt.plot(rf_freq,efficiency,'o--')
plt.xlabel('RF Frequency / MHz')
plt.ylabel(r'Diffraction Efficiency / $\%$')
plt.title('Efficiency of 1st-order diffraction from AOM as a function of RF frequency')
# plt.show()
plt.savefig('220615 aom efficiency vs rf freq'+'.pdf',bbox_inches='tight',dpi=300)

# %% [markdown]
# 2

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '150622'
row_start = 26
row_end = 40

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

df = df.sort_values('attenuation as a fct of rf power at 350 MHz')

rf_inputpower = df.iloc[:,6]
efficiency2 = df.iloc[:,3]*100

plt.figure(figsize=(9,6))
plt.plot(rf_inputpower,efficiency2,'o--')
plt.xlabel('RF Power / W')
plt.ylabel(r'Diffraction Efficiency / $\%$')
plt.title('Efficiency of 1st-order diffraction from AOM as a function of RF power')
# plt.show()
plt.savefig('220615 aom efficiency vs rf power'+'.pdf',bbox_inches='tight',dpi=300)

# %% [markdown]
# 3

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '150622'
row_start = 64
row_end = 72

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

df = df.sort_values('freq / MHz')

freq = df.iloc[:,1]
hor_pos = df.iloc[:,2]

plt.figure(figsize=(9,6))
plt.plot(freq,hor_pos,'o--')
plt.xlabel('RF Frequency / MHz')
plt.ylabel(r'Horizontal Position / $\mu$m')
plt.title('Horizontal position of first-order diffracted beam against RF frequency')
# plt.show()
plt.savefig('220615 aom hor pos vs freq'+'.pdf',bbox_inches='tight',dpi=300)

# %% [markdown]
# Other previous plots

# %%
filename = 'msquared 689 long term power.xlsx'
row_start = 7
row_end = 39

df = pd.read_excel(filename,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# remove points where o/p power is < 3.5W cos that's during opt

drop_index = [i for i in range(len(df.iloc[:,1])) if df.iloc[i,1] < 3.8] 

df = df.drop(drop_index);

df['Date'] =  pd.to_datetime(df['Date'], format='%d%b%Y:%H:%M:%S.%f') # change format

datetime = df.iloc[:,0]
highpower = df.iloc[:,1]
voltagepd = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(9,6))
ax1.plot(datetime,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(datetime,voltagepd,'ro',alpha=0.5,label='PD voltage')

fig.autofmt_xdate(rotation=45) # rotate date xlabels
import matplotlib.dates as mdates
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=6)) #set freq of xticks to plot date every 6 days

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Datetime')
ax2.set_ylabel('Solstis internal diode output PD / V')
plt.title('Long term power drifts')
fig.legend(loc='upper left',bbox_to_anchor=(0.625,0.885))
# plt.show()
plt.savefig('689_longtermpowerdrifts'+'.pdf',bbox_inches='tight',dpi=300)

# %%
# 160322 data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '160322 P'
row_start = 3
row_end = 25

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# Power Curve + internal photodiode

pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
voltagepd = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(7.5,6))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage, ' + '2022-03-16')
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
# plt.show()
plt.savefig('160322 power pd vs pump'+'.pdf',bbox_inches='tight',dpi=300)

# %%
# 180322 data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '180322 P'
row_start = 3
row_end = 20

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# Power Curve + internal photodiode

pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
voltagepd = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(7.5,6))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage, ' + '2022-03-18')
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
# plt.show()
plt.savefig('180322 power pd vs pump'+'.pdf',bbox_inches='tight',dpi=300)

# %%
# 250322 p data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '250322 P'
row_start = 8
row_end = 22

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# current and temp (lazy change variable name)

pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
voltagepd = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(9,6))
ax1.plot(pumppower,highpower,'bo',label='Diode current')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='Diode temperature')

ax1.set_ylabel('Diode current / A')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel(r'Pump diode tempearture / $^o$C')
datetime = time.strftime("%Y-%m-%d")
plt.title('Pump diode temperature and current profile, ' + '2022-03-25')
fig.legend(loc='upper left',bbox_to_anchor=(0.60,0.85))
# plt.show()
plt.savefig('250322 temp current vs pump'+'.pdf',bbox_inches='tight',dpi=300)

# %%
# 250322 p data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '250322 P'
row_start = 8
row_end = 22

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# Power Curve + fibre 

pumppower = df.iloc[:,1]
highpower = df.iloc[:,5]
voltagepd = df.iloc[:,4]
fibre = df.iloc[:,7]

fig, ax1 = plt.subplots(figsize=(7.5,6))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,fibre,'ro',alpha=0.5,label='Fibre launch power')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel(r'Fibre launch module power (low power PM) / $\mu$W')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and fibre launch power, ' + '2022-03-25')
fig.legend(loc='upper left',bbox_to_anchor=(0.125,0.875))
# plt.show()
plt.savefig('250322 output p fibre vs pump'+'.pdf',bbox_inches='tight',dpi=300)

# %%
# 250322 lambda data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '250322 λ'
row_start = 4
row_end = 11

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
wavelength = df.iloc[:,4]

fig, ax1 = plt.subplots(figsize=(7.5,6))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength, ' + '2022-03-25')
fig.legend(loc='upper left',bbox_to_anchor=(0.60,0.35))
# plt.show()
plt.savefig('250322 power wavelength vs pump'+'.pdf',bbox_inches='tight',dpi=300)

# %%
# Power Curve + internal photodiode

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '050522'
row_start = 2
row_end = 10

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
wavelength = df.iloc[:,2]
voltagepd = df.iloc[:,3]
datetime = df.iloc[:,4] 

time_hm = datetime

time_hm = datetime.dt.strftime("%H:%M")
# time_hm #time in hours and minutes

time_hm = pd.to_datetime(time_hm)
# time_hm

fig, ax = plt.subplots(3, sharex=True,figsize=(9,9))
date = time.strftime("%Y-%m-%d")
fig.suptitle('Power, Photodiode Voltage and Wavelength fluctuations in an hour, ' + '2022-05-05')

ax[0].plot(time_hm, highpower,'bo',label='Output power')
ax[0].set_ylabel('Output Power / W')

ax[1].plot(time_hm, voltagepd, 'ro',alpha=0.75,label='PD voltage')
ax[1].set_ylabel('PD Voltage / V')

ax[2].plot(time_hm, wavelength, 'go',alpha=0.75,label='Wavelength')
ax[2].set_ylabel('Wavelength / nm')

ax[0].xaxis.set_major_locator(mdates.MinuteLocator(interval=10)) #set freq of xticks

plt.xticks(rotation=90)
# plt.show()
plt.savefig('220505 onehour_fluctuations2'+'.pdf',bbox_inches='tight',dpi=300)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import time as time
plt.rcParams['text.usetex'] = True
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 18
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['xtick.major.size'] = 5.0
plt.rcParams['xtick.minor.size'] = 3.0
plt.rcParams['ytick.major.size'] = 5.0
plt.rcParams['ytick.minor.size'] = 3.0
plt.rcParams['legend.handlelength'] = 1.0

# %% [markdown]
# # 160622 Plotting long term power drifts

# %%
filename = 'msquared 689 long term power.xlsx'
row_start = 7
row_end = 39

df = pd.read_excel(filename,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# %%
df
# Out:
#                   Date  Output Power / W  PD Voltage / V  \
# 0  2022-03-16 00:00:00             4.170           0.923
# 1  2022-03-18 00:00:00             4.590           0.867
# 2  2022-03-25 13:00:00             4.350           0.837
# 3  2022-03-25 17:00:00             4.041             NaN
# 4  2022-04-05 00:00:00             3.440           0.625
# 5  2022-04-07 11:00:00             2.745           0.461
# 6  2022-04-07 11:30:00             2.883           0.506
# 7  2022-04-07 12:00:00             3.030             NaN
# 8  2022-04-07 16:00:00             4.430           0.830
# 9  2022-04-07 18:00:00             4.415           1.030
# 10 2022-04-08 10:00:00             1.590           0.414
# 11 2022-04-08 10:30:00             4.327           0.860
# 12 2022-04-20 10:00:00             3.650           0.844
# 13 2022-04-20 00:00:00             3.950           0.900
# 14 2022-04-20 15:00:00             4.130           0.964
# ...

# %%
# remove points where o/p power is < 3.5W cos that's during opt

drop_index = [i for i in range(len(df.iloc[:,1])) if df.iloc[i,1] < 3.8]

# %%
drop_index
# Out:
# [4, 5, 6, 7, 10, 12, 16]

# %%
df = df.drop(drop_index);

# %%
df['Date'] =  pd.to_datetime(df['Date'], format='%d%b%Y:%H:%M:%S.%f') # change format

# %%
datetime = df.iloc[:,0]
highpower = df.iloc[:,1]
voltagepd = df.iloc[:,2]

# %%
fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(datetime,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(datetime,voltagepd,'ro',alpha=0.5,label='PD voltage')

fig.autofmt_xdate(rotation=45) # rotate date xlabels
import matplotlib.dates as mdates
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=6)) #set freq of xticks to plot date every 6 days

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Datetime')
ax2.set_ylabel('Solstis internal diode output PD / V')
plt.title('Long term power drifts')
fig.legend(loc='upper left',bbox_to_anchor=(0.675,0.85))
plt.show()

# %% [markdown]
# # 160622 Plotting Old Data Graphs

# %%
# 160322 data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = input('Enter sheet name in excel file: ')
row_start = input('Enter row number where your data starts: ')
row_end = input('Enter row number where your data ends: ')

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)
# Out:
# Enter sheet name in excel file: 160322 P
# Enter row number where your data starts: 3
# Enter row number where your data ends: 25

# %%
df
# Out:
#     Unnamed: 0  Pump Power / W  Internal diode  output PD / V  \
# 0          NaN             0.0                          0.000
# 1          NaN             0.5                          0.001
# 2          NaN             1.0                          0.002
# 3          NaN             2.0                          0.004
# 4          NaN             3.0                          0.006
# 5          NaN             4.0                          0.008
# 6          NaN             5.0                          0.010
# 7          NaN             6.0                          0.012
# 8          NaN             7.0                          0.035
# 9          NaN             6.5                          0.013
# 10         NaN             7.0                          0.043
# 11         NaN             7.5                          0.052
# 12         NaN             8.0                          0.058
# 13         NaN             9.0                          0.096
# ...

# %%
# Power Curve + internal photodiode

pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
voltagepd = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage, ' + '2022-03-16')
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# 180322 data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = input('Enter sheet name in excel file: ')
row_start = input('Enter row number where your data starts: ')
row_end = input('Enter row number where your data ends: ')

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)
# Out:
# Enter sheet name in excel file: 180322 P
# Enter row number where your data starts: 3
# Enter row number where your data ends: 20

# %%
df
# Out:
#     Unnamed: 0  Pump Power / W  Internal diode  output PD / V  \
# 0          NaN               4                          0.006
# 1          NaN               7                          0.061
# 2          NaN               8                          0.073
# 3          NaN               9                          0.112
# 4          NaN              10                          0.146
# 5          NaN              11                          0.309
# 6          NaN              12                          0.425
# 7          NaN              15                          0.660
# 8          NaN              18                          0.910
# 9          NaN               4                          0.006
# 10         NaN               7                          0.063
# 11         NaN               8                          0.071
# 12         NaN               9                          0.108
# 13         NaN              10                          0.141
# ...

# %%
# Power Curve + internal photodiode

pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
voltagepd = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage, ' + '2022-03-18')
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# 250322 p data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '250322 P'
row_start = 8
row_end = 22

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN         0.0       25.06       10.08       0.000      0.0000
# 1          NaN         4.0       24.95       10.08       0.006      0.0000
# 2          NaN         6.5       24.90       10.08       0.010      0.0002
# 3          NaN         7.0       24.90       10.08       0.040      0.1760
# 4          NaN         8.0       24.85       10.06       0.060      0.2050
# 5          NaN         9.0       24.86       10.06       0.092      0.3400
# 6          NaN        10.0       24.86       10.06       0.132      0.4800
# 7          NaN        11.0       24.87       10.06       0.280      1.4900
# 8          NaN        12.0       24.87       10.06       0.389      2.0130
# 9          NaN        13.0       24.86       10.06       0.483      2.4700
# 10         NaN        14.0       24.86       10.06       0.556      2.8350
# ...

# %%
# current and temp (lazy change variable name)

pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
voltagepd = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Diode current')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='Diode temperature')

ax1.set_ylabel('Diode current / A')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel(r'Pump diode tempearture / $^o$C')
datetime = time.strftime("%Y-%m-%d")
plt.title('Pump diode temperature and current profile, ' + '2022-03-25')
fig.legend(loc='upper left',bbox_to_anchor=(0.60,0.85))
plt.show()

# %%
# Power Curve + fibre 

pumppower = df.iloc[:,1]
highpower = df.iloc[:,5]
voltagepd = df.iloc[:,4]
fibre = df.iloc[:,7]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,fibre,'ro',alpha=0.5,label='Fibre launch power')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel(r'Fibre launch module power (low power PM) / $\mu$W')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and fibre launch power, ' + '2022-03-25')
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# 250322 lambda data

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = input('Enter sheet name in excel file: ')
row_start = input('Enter row number where your data starts: ')
row_end = input('Enter row number where your data ends: ')

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)
# Out:
# Enter sheet name in excel file: 250322 λ
# Enter row number where your data starts: 4
# Enter row number where your data ends: 11

# %%
pumppower = df.iloc[:,1]
highpower = df.iloc[:,3]
wavelength = df.iloc[:,4]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength, ' + '2022-03-25')
fig.legend(loc='upper left',bbox_to_anchor=(0.60,0.35))
plt.show()

# %% [markdown]
# # 150622 Plotting AOM graphs
#
# 1. Power diffracted into first order i.e. efficiency as a fn of RF frequeny
# 2. Power diffracted into first order i.e. efficiency as a fn of attenuation i.e. RF power
# 3. Horizontal beam position of first order diffracted beam as a fn of RF frequency.

# %% [markdown]
# (1) Power diffracted into first order i.e. efficiency as a fn of RF frequeny

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '150622'
row_start = 8
row_end = 22

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# %%
df
# Out:
#     Unnamed: 0  RF frequency / MHz  power diffracted into 1st order /W  \
# 0          NaN                 350                            0.000747
# 1          NaN                 340                            0.000356
# 2          NaN                 330                            0.000072
# 3          NaN                 320                            0.000001
# 4          NaN                 310                            0.000048
# 5          NaN                 300                            0.000007
# 6          NaN                 360                            0.000313
# 7          NaN                 370                            0.000065
# 8          NaN                 380                            0.000034
# 9          NaN                 390                            0.000007
# 10         NaN                 400                            0.000004
# 11         NaN                 355                            0.000621
# ...

# %%
df = df.sort_values('RF frequency / MHz')
df
# Out:
#     Unnamed: 0  RF frequency / MHz  power diffracted into 1st order /W  \
# 5          NaN                 300                            0.000007
# 4          NaN                 310                            0.000048
# 3          NaN                 320                            0.000001
# 2          NaN                 330                            0.000072
# 13         NaN                 335                            0.000155
# 1          NaN                 340                            0.000356
# 12         NaN                 345                            0.000612
# 0          NaN                 350                            0.000747
# 11         NaN                 355                            0.000621
# 6          NaN                 360                            0.000313
# 14         NaN                 365                            0.000112
# 7          NaN                 370                            0.000065
# ...

# %%
rf_freq = df.iloc[:,1]
efficiency = df.iloc[:,3] * 100

# %%
plt.figure(figsize=(10,8))
plt.plot(rf_freq,efficiency,'o--')
plt.xlabel('RF Frequency / MHz')
plt.ylabel(r'Diffraction Efficiency / $\%$')
plt.title('Efficiency of 1st-order diffraction from AOM as a function of RF frequency')
plt.show()

# %% [markdown]
# (2) Power diffracted into first order i.e. efficiency as a fn of attenuation i.e. RF power

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '150622'
row_start = 26
row_end = 40

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# %%
df
# Out:
#     Unnamed: 0  attenuation as a fct of rf power at 350 MHz  Unnamed: 2  \
# 0          NaN                                          8.0    0.000760
# 1          NaN                                          8.5    0.000755
# 2          NaN                                          7.5    0.000758
# 3          NaN                                          9.0    0.000732
# 4          NaN                                         10.0    0.000685
# 5          NaN                                         11.0    0.000616
# 6          NaN                                         12.0    0.000531
# 7          NaN                                         13.0    0.000460
# 8          NaN                                         14.0    0.000389
# 9          NaN                                         15.0    0.000326
# 10         NaN                                         16.0    0.000257
# 11         NaN                                         17.0    0.000213
# ...

# %%
df = df.sort_values('attenuation as a fct of rf power at 350 MHz')

# %%
rf_inputpower = df.iloc[:,6]

efficiency2 = df.iloc[:,3]*100

# %%
plt.figure(figsize=(10,8))
plt.plot(rf_inputpower,efficiency2,'o--')
plt.xlabel('RF Power / W')
plt.ylabel(r'Diffraction Efficiency / $\%$')
plt.title('Efficiency of 1st-order diffraction from AOM as a function of RF power')
plt.show()

# %%
# attn = df.iloc[:,1]

# %%
# plt.figure(figsize=(10,8))
# plt.plot(attn,rf_inputpower,'o--')
# plt.ylabel('RF Power / W')
# plt.xlabel('Attenuation / arb.')
# plt.title('Measured RF power as a function of attenuation')
# plt.show()

# %% [markdown]
# (3)  Horizontal beam position of first order diffracted beam as a fn of RF frequency.

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '150622'
row_start = 64
row_end = 72

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# %%
df
# Out:
#    Unnamed: 0  freq / MHz  Hor pos / um  \
# 0         NaN         350        2226.0
# 1         NaN         340        1795.0
# 2         NaN         330           NaN
# 3         NaN         360        2652.0
# 4         NaN         370           NaN
# 5         NaN         345        2016.0
# 6         NaN         355        2435.0
# 7         NaN         365           NaN
# 8         NaN         335           NaN
#
#   Height of camera was elevated slightly by about 3-4mm for better viewing.  \
# 0                                                NaN
# 1                                                NaN
# 2                                           clippinh
# 3                                                NaN
# 4                                           clipping
# 5                                                NaN
# 6                                                NaN
# 7                                           clipping
# ...

# %%
df = df.sort_values('freq / MHz')

# %%
freq = df.iloc[:,1]
hor_pos = df.iloc[:,2]

# %%
plt.figure(figsize=(10,8))
plt.plot(freq,hor_pos,'o--')
plt.xlabel('RF Frequency / MHz')
plt.ylabel(r'Horizontal Position / $\mu$m')
plt.title('Horizontal position of first-order diffracted beam against RF frequency')
plt.show()

# %% [markdown]
# # 070422 Writing script for plotting files from excel data easily
#
# Analyzed data: 050422 power

# %%
excel_filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '050422 power' #name of sheet to analyze
header_no = 6 #start extracting data from this row (choose the row with the title)

df = pd.read_excel(excel_filename,sheet_name=sheetname,header=header_no)

# %%
df
# Out:
#     Pump Power / W  Pump - pump diode Tempearture / C  Diode current / A  \
# 0                7                              25.10              10.12
# 1               12                              25.12              10.12
# 2               18                              25.05              10.12
# 3               11                              25.02              10.12
# 4               14                              25.02              10.12
# 5               10                              25.03              10.12
# 6               18                              25.03              10.12
# 7               11                              25.02              10.12
# 8               10                              25.02              10.12
# 9               14                              25.00              10.12
# 10               7                              25.00              10.12
# 11              12                              25.00              10.12
#
# ...

# %%
# Power Curve + fibre launch

pumppower = df.iloc[:,0]
highpower = df.iloc[:,4]
lowpower = df.iloc[:,5]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,lowpower,'ro',alpha=0.5,label='Fibre launch power')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Fibre launch power (low power PM) / uW')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and fibre launch, ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# Power Curve + internal photodiode

pumppower = df.iloc[:,0]
highpower = df.iloc[:,4]
voltagepd = df.iloc[:,3]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage, ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# Power Curve + wavelength1, post optimization

excel_filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '070422 wavelength1' #name of sheet to analyze
header_no = 6 #start extracting data from this row (choose the row with the title)

df = pd.read_excel(excel_filename,sheet_name=sheetname,header=header_no)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
wavelength = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength, post-optimization ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %% [markdown]
# #  070422 Analyzing data for 070422 data

# %%
# Power Curve + internal photodiode, pre=optimization

excel_filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '070422 pre-opt' #name of sheet to analyze
header_no = 6 #start extracting data from this row (choose the row with the title)

df = pd.read_excel(excel_filename,sheet_name=sheetname,header=header_no)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,4]
voltagepd = df.iloc[:,3]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage, pre-optimization ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# Power Curve + internal photodiode, post optimization

excel_filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '070422 post-opt' #name of sheet to analyze
header_no = 6 #start extracting data from this row (choose the row with the title)

df = pd.read_excel(excel_filename,sheet_name=sheetname,header=header_no)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,4]
voltagepd = df.iloc[:,3]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage, post-optimization ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# Power Curve + wavelength1, post optimization

excel_filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '070422 wavelength1' #name of sheet to analyze
header_no = 6 #start extracting data from this row (choose the row with the title)

df = pd.read_excel(excel_filename,sheet_name=sheetname,header=header_no)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
wavelength = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength, post-optimization ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# Power Curve + wavelength2, post optimization

excel_filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '070422 wavelength2' #name of sheet to analyze
header_no = 8 #start extracting data from this row (choose the row with the title)

df = pd.read_excel(excel_filename,sheet_name=sheetname,header=header_no)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,4]
wavelength = df.iloc[:,5]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength, post-optimization ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %% [markdown]
# # 080422 Add argument for data in excel where row ends, use 080422 data. This now allows dynamic plotting of which row we want.

# %%
filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '070422 wavelength1'
row_start = 3
row_end = 19

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
wavelength = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength, ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %% [markdown]
# # 200422 More data plots for power curve

# %%
# Power Curve + internal photodiode

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '200422'
row_start = 12
row_end = 18

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
voltagepd = df.iloc[:,3]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# Power Curve + wavelength 

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '200422'
row_start = 12
row_end = 18

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
wavelength = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %% [markdown]
# ### Then did more one shot alignment after fully reoptimizing

# %%
# Power Curve + internal photodiode

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '200422'
row_start = 33
row_end = 40

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
voltagepd = df.iloc[:,3]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,voltagepd,'ro',alpha=0.5,label='PD voltage')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Solstis internal diode output PD / V')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and internal photodiode voltage ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %%
# Power Curve + wavelength 

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '200422'
row_start = 33
row_end = 40

pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
wavelength = df.iloc[:,2]

fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(pumppower,highpower,'bo',label='Output power')
ax2 = ax1.twinx()
ax2.plot(pumppower,wavelength,'ro',alpha=0.5,label='Wavelength')

ax1.set_ylabel('Output power (high power PM) / W')
ax1.set_xlabel('Pump power / W')
ax2.set_ylabel('Wavelength / nm')
datetime = time.strftime("%Y-%m-%d")
plt.title('Power curve and wavelength ' + datetime)
fig.legend(loc='upper left',bbox_to_anchor=(0.15,0.85))
plt.show()

# %% [markdown]
# # 050522 Plotting Power Fluctuations/Drifts over time. First we look at power every 10min within an hour.

# %%
# Power Curve + internal photodiode

filename = 'msquared 689 characterization measurements.xlsx'
sheetname = '050522'
row_start = 2
row_end = 10

df = pd.read_excel(filename,sheet_name=sheetname,header=int(row_start)-2,nrows=int(row_end)-int(row_start)+1)

# %%
pumppower = df.iloc[:,0]
highpower = df.iloc[:,1]
wavelength = df.iloc[:,2]
voltagepd = df.iloc[:,3]
datetime = df.iloc[:,4]

# %%
time_hm = datetime

# %%
time_hm = datetime.dt.strftime("%H:%M")
time_hm #time in hours and minutes
# Out:
# 0    10:14
# 1    10:16
# 2    10:28
# 3    10:35
# 4    10:45
# 5    10:55
# 6    11:04
# 7    11:14
# 8    11:24
# Name: Datetime, dtype: object

# %%
time_hm = pd.to_datetime(time_hm)
time_hm
# Out:
# 0   2022-06-16 10:14:00
# 1   2022-06-16 10:16:00
# 2   2022-06-16 10:28:00
# 3   2022-06-16 10:35:00
# 4   2022-06-16 10:45:00
# 5   2022-06-16 10:55:00
# 6   2022-06-16 11:04:00
# 7   2022-06-16 11:14:00
# 8   2022-06-16 11:24:00
# Name: Datetime, dtype: datetime64[ns]

# %%
fig, ax = plt.subplots(3, sharex=True,figsize=(10,10))
date = time.strftime("%Y-%m-%d")
fig.suptitle('Power, Photodiode Voltage and Wavelength fluctuations in an hour, ' + '2022-05-05')

ax[0].plot(time_hm, highpower,'bo',label='Output power')
ax[0].set_ylabel('Output Power / W')

ax[1].plot(time_hm, voltagepd, 'ro',alpha=0.75,label='PD voltage')
ax[1].set_ylabel('PD Voltage / V')

ax[2].plot(time_hm, wavelength, 'go',alpha=0.75,label='Wavelength')
ax[2].set_ylabel('Wavelength / nm')

ax[0].xaxis.set_major_locator(mdates.MinuteLocator(interval=10)) #set freq of xticks

plt.xticks(rotation=90)
plt.show()

# %%
# fig.autofmt_xdate(rotation=45) # rotate date xlabels
# import matplotlib.dates as mdates
# ax[0].xaxis.set_major_locator(mdates.MinuteLocator(interval=10)) #set freq of xticks
