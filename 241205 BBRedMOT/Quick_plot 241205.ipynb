# %%
from mot_analysis.motimg import MOTImaging
# blue mot tof flight measurement
import os
import glob
import h5py 
import json
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
# # ## WINDOWS: On your .ipynb, import this plotting_style by adding in and uncommenting the following lines:
# # import matplotlib.pyplot as plt
# # import sys
# # sys.path.append('C:/Users/Michael/Dropbox/AION/Projects')  # Replace with the relevant path that contains this script
# # from plotting_style import set_plotting_style
# # set_plotting_style()

# # ## MAC: On your .ipynb, import this plotting_style by adding in and uncommenting the following lines:
# # # import matplotlib.pyplot as plt
# # # import sys
# # # sys.path.append('/Users/michael/Dropbox/AION/Projects')  # Replace with the relevant path that contains this script
# # # from plotting_style import set_plotting_style
# # # set_plotting_style()


# # import matplotlib.pyplot as plt

# # print('Initialising plotting style...')

# def set_plotting_style():
#     plt.rc("font", family = 'Arial', size=10)
#     plt.rc('axes', labelsize=20, titlesize = 20, labelpad=5)
#     plt.rc('xtick', labelsize=18)
#     plt.rc('ytick', labelsize=18)
#     plt.rc('legend', fontsize=15)

# set_plotting_style()


# # print('Success! Plotting style initialised.')

# %% [markdown]
# # Import and quick plot

# %%
# file name and path
file_path = r"/Volumes/MBQD_data/AION/Data/2024/12/05/mot_ndscan/000017872-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x1 = h5file['datasets/ndscan.rid_17872.points.axis_0'][:]
    y1 = h5file['datasets/ndscan.rid_17872.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x1 = np.delete(x1, 4)
y1 = np.delete(y1, 4)


# Plotting the data#
plt.figure(figsize=(12, 10))

plt.plot(x1/1e6, y1/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Red DPAOM frequency (MHz)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
ax2 = plt.twiny()
frequencyoffsetfromcavity = x1/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity, y1/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT spectroscopy', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI
# plt.savefig('241205 Broadband red MOT spectroscopy 1.pdf', dpi=1200)

plt.show()
# Out:
# /var/folders/4c/r3ydc0x11r9d96q94sm46lhr0000gq/T/ipykernel_55455/1341264224.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=20)

# %%
# file name and path
file_path = r"/Volumes/MBQD_data/AION/Data/2024/12/05/mot2_ndscan/000017874-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x2 = h5file['datasets/ndscan.rid_17874.points.axis_0'][:]
    y2 = h5file['datasets/ndscan.rid_17874.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x2 = np.delete(x2, 7)
y2 = np.delete(y2, 7)

x2 = np.delete(x2, 8)
y2 = np.delete(y2, 8)

x2 = np.delete(x2, 8)
y2 = np.delete(y2, 8)


# Plotting the data#
plt.figure(figsize=(12, 10))

plt.plot(x2/1e6, y2/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Red DPAOM frequency (MHz)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
ax2 = plt.twiny()
frequencyoffsetfromcavity = x2/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity, y2/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT spectroscopy', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI
# plt.savefig('241205 Broadband red MOT spectroscopy 2.pdf', dpi=1200)

plt.show()
# Out:
# /var/folders/4c/r3ydc0x11r9d96q94sm46lhr0000gq/T/ipykernel_55455/86089043.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=20)

# %%
# file name and path
file_path = r"/Volumes/MBQD_data/AION/Data/2024/12/05/mot3_ndscan/000017875-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x3 = h5file['datasets/ndscan.rid_17875.points.axis_0'][:]
    y3 = h5file['datasets/ndscan.rid_17875.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x3 = np.delete(x3, 18)
y3 = np.delete(y3, 18)

# Plotting the data#
plt.figure(figsize=(12, 10))

plt.plot(x3/1e6, y3/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Red DPAOM frequency (MHz)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
ax2 = plt.twiny()
frequencyoffsetfromcavity = x3/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity, y3/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT spectroscopy', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI
# plt.savefig('241205 Broadband red MOT spectroscopy 3.pdf', dpi=1200)

plt.show()
# Out:
# /var/folders/4c/r3ydc0x11r9d96q94sm46lhr0000gq/T/ipykernel_55455/609436290.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=20)

# %%
plt.figure(figsize=(10, 6))

# plt.plot(x1[:9]/1e6, y1[:9]/10, 'o-', markersize = 20)  # Large dots and connected points
# plt.plot(x2/1e6, y2/10, 'o-', markersize = 20)  # Large dots and connected points
# plt.plot(x3[-9:]/1e6, y3[-9:]/10, 'o-', markersize = 20)  # Large dots and connected points

x_combined = np.concatenate((x1[:9], x2, x3[-9:]))
y_combined = np.concatenate((y1[:9], y2, y3[-9:]))
plt.plot(x_combined/1e6, y_combined/10, 'o-', markersize = 15)  # Large dots and connected points

# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Red DPAOM frequency (MHz)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
# plt.legend(fontsize=20)

plt.title('Broadband red MOT spectroscopy', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI

ax2 = plt.twiny()
frequencyoffsetfromcavity1 = x1/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity1, y1/10, 'o-', alpha=0)  # Large dots and connected points
frequencyoffsetfromcavity2 = x2/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity2, y2/10, 'o-', alpha=0)  # Large dots and connected points
frequencyoffsetfromcavity3 = x3/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity3, y3/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
ax2.tick_params(axis='x', which='major', labelsize=20)


# plt.savefig('241205 Broadband red MOT spectroscopy combined.pdf', dpi=1200, bbox_inches='tight')

plt.show()

# %% [markdown]
# # 250501 Replot the above with nice LaTex font

# %%
# copy paste this code to the beginning of your script to set the plotting style for a one column figure

from matplotlib import pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "figure.constrained_layout.use": True
})

plt.rcParams["savefig.bbox"] = None
plt.rcParams["figure.figsize"] = (5.9,4)  # (width, height) in inches, change height but not width
plt.rcParams["figure.titlesize"] = 10 # this is only for plt.suptitle, i set it to be the same as the rest

plt.rcParams["axes.titlesize"] = 10 # control title size
plt.rcParams["axes.labelsize"] = 10 # control x and y axis labels
plt.rcParams["axes.labelpad"] = 4.0 # distance between axis label and axis numbers
plt.rcParams["xtick.labelsize"] = 10 # independent control of xlabel fontsize
plt.rcParams["ytick.labelsize"] = 10 # independent control of ylabel fontsize

plt.rcParams["legend.fontsize"] = 7.5 # control legend size, I set it to be slightly smaller than title/axes label
# plt.rcParams["legend.facecolor"] = (0.9, 0.9, 0.9) # legend background color
# plt.rcParams["legend.edgecolor"] = (0, 0, 0) # legend border line color
# plt.rcParams["legend.frameon"] = True # whether or not to draw a border around legend
# plt.rcParams["legend.framealpha"] = 0.1 # legend background transparency
plt.rcParams["legend.loc"] = "best" # default legend location
plt.rcParams["legend.handletextpad"] = 0.8  # Horizontal space between legend point and text (default 0.8)
plt.rcParams["legend.labelspacing"] = 0.6  # Vertical space between legend entries (default 0.5)
# plt.rcParams["legend.columnspacing"] = 2.0  # Space between columns in multi-column legends
# plt.rcParams["legend.borderpad"] = 1.0  # Space between legend content and the box
# plt.rcParams["legend.handlelength"] = 2.0  # Length of legend marker lines

plt.rcParams["lines.linewidth"] = 1
plt.rcParams["lines.markersize"] = 6 #data point size

# CHOOSE NICE COLOR FOR DARK MARKER EDGEWIDTH FROM "dodgerblue","mediumseagreen","crimson","mediumpurple","slateblue","darkorange","peru","goldenrod"
plt.rcParams["lines.linewidth"] = 1
plt.rcParams["lines.markersize"] = 6 #data point size
plt.rcParams["lines.markeredgewidth"] = 1.5 # width of the edge of the marker
plt.rcParams["lines.markeredgecolor"] = "black" # color of the edge of the marker
plt.rcParams["lines.markerfacecolor"] = "crimson" # color of the inside of the marker
plt.rcParams["lines.marker"] = "o" # marker type, see https://matplotlib.org/stable/api/markers_api.html for all options
plt.rcParams["lines.color"] = "black" # color of the line
# CHOOSE NICE COLOR FOR DARK MARKER EDGEWIDTH FROM "dodgerblue","mediumseagreen","crimson","mediumpurple","slateblue","darkorange","peru","goldenrod"


plt.rcParams["grid.linestyle"] = "--"
plt.rcParams['axes.grid'] = True
# plt.rcParams["grid.linewidth"] = 0.7

# plt.rcParams["xtick.major.pad"] = 4.0 # distance between xticks dashes and xaxis numbers
# plt.rcParams["xtick.major.size"] = 3.0
# plt.rcParams["xtick.major.width"] = 0.7
# plt.rcParams["ytick.major.pad"] = 4.0 # distance between yticks dashes and yaxis numbers
# plt.rcParams["ytick.major.size"] = 3.0
# plt.rcParams["ytick.major.width"] = 0.7

# %%
# plt.plot(x1[:9]/1e6, y1[:9]/10, 'o-', markersize = 20)  # Large dots and connected points
# plt.plot(x2/1e6, y2/10, 'o-', markersize = 20)  # Large dots and connected points
# plt.plot(x3[-9:]/1e6, y3[-9:]/10, 'o-', markersize = 20)  # Large dots and connected points

x_combined = np.concatenate((x1[:9], x2, x3[-9:]))
y_combined = np.concatenate((y1[:9], y2, y3[-9:]))
plt.plot(x_combined/1e6, y_combined/10, 'ko-')  # Large dots and connected points

# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.xlabel('Red DPAOM frequency (MHz)')
plt.ylabel(r'Transfer Efficiency $\eta_{MOT}$')
# plt.legend(fontsize=20)

# plt.title('Broadband red MOT spectroscopy',pad=8)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
# # Adjust layout to prevent cut off
# # Save the plot with 300 DPI

ax2 = plt.twiny()
frequencyoffsetfromcavity1 = x1/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity1, y1/10, 'o-', alpha=0)  # Large dots and connected points
frequencyoffsetfromcavity2 = x2/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity2, y2/10, 'o-', alpha=0)  # Large dots and connected points
frequencyoffsetfromcavity3 = x3/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity3, y3/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel(r'Frequency offset from cavity $f_{cavityoffset}$ (MHz)',labelpad=8)


plt.savefig('250501 BBRedMOTSpectroscopyCombined.pdf', dpi=300)

# %%
x_combined[-6]/1e6*2 + 460 - 100
# Out:
# 1063.6

# %%
# file name and path
file_path = r"Z:\AION\Data\2024\12\05\bbII1_ndscan\000017886-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x = h5file['datasets/ndscan.rid_17886.points.axis_0'][:]
    y = h5file['datasets/ndscan.rid_17886.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x = np.delete(x, 6)
y = np.delete(y, 6)

x = np.delete(x, 8)
y = np.delete(y, 8)

# Plotting the data#
plt.figure(figsize=(12, 10))

plt.plot(x/1e6, y/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Red DPAOM frequency (MHz)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
ax2 = plt.twiny()
frequencyoffsetfromcavity = x/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity, y/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT II spectroscopy', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)

plt.grid()

# # Adjust layout to prevent cut off
plt.tight_layout()

# # Save the plot with 300 DPI
plt.savefig('241205 Broadband red MOT II spectroscopy.pdf', dpi=1200)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# file name and path
file_path = r"Z:\AION\Data\2024\12\05\bbII2_ndscan\000017887-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x = h5file['datasets/ndscan.rid_17887.points.axis_0'][:]
    y = h5file['datasets/ndscan.rid_17887.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

# x = np.delete(x, 18)
# y = np.delete(y, 18)

# Plotting the data#
plt.figure(figsize=(12, 10))

plt.plot(x/1e6, y/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Red DPAOM frequency (MHz)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
ax2 = plt.twiny()
frequencyoffsetfromcavity = x/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity, y/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT II spectroscopy', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI
plt.savefig('241205 Broadband red MOT II spectroscopy 2.pdf', dpi=1200)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# file name and path
file_path = r"Z:\AION\Data\2024\12\05\bbII3_ndscan\000017888-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x = h5file['datasets/ndscan.rid_17888.points.axis_0'][:]
    y = h5file['datasets/ndscan.rid_17888.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x = np.delete(x, 8)
y = np.delete(y, 8)

x = np.delete(x, 13)
y = np.delete(y, 13)
x = np.delete(x, 13)
y = np.delete(y, 13)
x = np.delete(x, 13)
y = np.delete(y, 13)
x = np.delete(x, 13)
y = np.delete(y, 13)


# Plotting the data#
plt.figure(figsize=(8, 6))

plt.plot(x, y/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xticks(np.arange(0, 1.1, 0.1))
plt.xlabel('Broadband red MOT stage II duration (s)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
# plt.legend(fontsize=20)
# ax2 = plt.twiny()
# frequencyoffsetfromcavity = x/1e6 *2 + 460 - 100
# ax2.plot(frequencyoffsetfromcavity, y/10, 'o-', alpha=0)  # Large dots and connected points
# ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
# ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT II hold duration', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI
plt.savefig('241205 Broadband red MOT II hold duration.pdf', dpi=1200)

# plt.show()

# %%
# file name and path
file_path = r"Z:\AION\Data\2024\12\05\bbII4_ndscan\000017889-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x = h5file['datasets/ndscan.rid_17889.points.axis_0'][:]
    y = h5file['datasets/ndscan.rid_17889.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

# x = np.delete(x, 8)
# y = np.delete(y, 8)

# x = np.delete(x, 13)
# y = np.delete(y, 13)
# x = np.delete(x, 13)
# y = np.delete(y, 13)
# x = np.delete(x, 13)
# y = np.delete(y, 13)
# x = np.delete(x, 13)
# y = np.delete(y, 13)


# Plotting the data#
plt.figure(figsize=(8, 6))

plt.plot(x, y/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xticks(np.arange(0.01, 0.11, 0.01))
plt.xlabel('Broadband red MOT stage II duration (s)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
# ax2 = plt.twiny()
# frequencyoffsetfromcavity = x/1e6 *2 + 460 - 100
# ax2.plot(frequencyoffsetfromcavity, y/10, 'o-', alpha=0)  # Large dots and connected points
# ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
# ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT II hold duration', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI
plt.savefig('241205 Broadband red MOT II hold duration 2.pdf', dpi=1200)

# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# file name and path
file_path = r"Z:\AION\Data\2024\12\05\bbII5_ndscan\000017890-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x = h5file['datasets/ndscan.rid_17890.points.axis_0'][:]
    y = h5file['datasets/ndscan.rid_17890.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x = np.delete(x, 1)
y = np.delete(y, 1)

# x = np.delete(x, 13)
# y = np.delete(y, 13)
# x = np.delete(x, 13)
# y = np.delete(y, 13)
# x = np.delete(x, 13)
# y = np.delete(y, 13)
# x = np.delete(x, 13)
# y = np.delete(y, 13)


# Plotting the data#
plt.figure(figsize=(8, 6))

plt.plot(x, y/10, 'o-', markersize = 20)  # Large dots and connected points



# # plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# # Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xticks(np.arange(0.01, 0.11, 0.01))
plt.xlabel('Broadband red MOT stage II duration (s)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
# ax2 = plt.twiny()
# frequencyoffsetfromcavity = x/1e6 *2 + 460 - 100
# ax2.plot(frequencyoffsetfromcavity, y/10, 'o-', alpha=0)  # Large dots and connected points
# ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
# ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Broadband red MOT II hold duration', fontsize=25, pad=12)

# #plt.xlim(340, 360)
# # plt.ylim(-0.05,0.95)
plt.grid(True)
# # Adjust layout to prevent cut off
plt.tight_layout()
# # Save the plot with 300 DPI
plt.savefig('241205 Broadband red MOT II hold duration 3.pdf', dpi=1200)

# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
