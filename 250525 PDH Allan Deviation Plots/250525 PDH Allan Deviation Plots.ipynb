# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# copy paste this code to the beginning of your script to set the plotting style for a two column figure

from matplotlib import pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    # "figure.constrained_layout.use": True
})

plt.rcParams["figure.autolayout"] = False # set to True if you want to use constrained_layout

plt.rcParams["savefig.bbox"] = None
plt.rcParams["figure.figsize"] = (5.9,2.5)
plt.rcParams["figure.titlesize"] = 10 # this is only for plt.suptitle, i set it to be the same as the rest

plt.rcParams["axes.titlesize"] = 10 # control title size
plt.rcParams["axes.labelsize"] = 10 # control x and y axis labels
plt.rcParams["axes.labelpad"] = 4.0 # distance between axis label and axis numbers
plt.rcParams["xtick.labelsize"] = 10 # independent control of xlabel fontsize
plt.rcParams["ytick.labelsize"] = 10 # independent control of ylabel fontsize

plt.rcParams["legend.fontsize"] = 7.5 # control legend size, I set it to be slightly smaller than title/axes label
# plt.rcParams["legend.facecolor"] = (0.9, 0.9, 0.9) # legend background color
# plt.rcParams["legend.edgecolor"] = (0, 0, 0) # legend border line color
# plt.rcParams["legend.frameon"] = True # whether or not to draw a border around legend
# plt.rcParams["legend.framealpha"] = 0.1 # legend background transparency
plt.rcParams["legend.loc"] = "upper left" # default legend location
plt.rcParams["legend.handletextpad"] = 0.8  # Horizontal space between legend point and text (default 0.8)
plt.rcParams["legend.labelspacing"] = 0.6  # Vertical space between legend entries (default 0.5)
# plt.rcParams["legend.columnspacing"] = 2.0  # Space between columns in multi-column legends
# plt.rcParams["legend.borderpad"] = 1.0  # Space between legend content and the box
# plt.rcParams["legend.handlelength"] = 2.0  # Length of legend marker lines

plt.rcParams["lines.linewidth"] = 1
plt.rcParams["lines.markersize"] = 6 #data point size

# CHOOSE NICE COLOR FOR DARK MARKER EDGEWIDTH FROM "dodgerblue","mediumseagreen","crimson","mediumpurple","slateblue","darkorange","peru","goldenrod"
# plt.rcParams["lines.linewidth"] = 1
# plt.rcParams["lines.markersize"] = 6 #data point size
# plt.rcParams["lines.markeredgewidth"] = 1.5 # width of the edge of the marker
# plt.rcParams["lines.markeredgecolor"] = "black" # color of the edge of the marker
# plt.rcParams["lines.markerfacecolor"] = "dodgerblue" # color of the inside of the marker
# plt.rcParams["lines.marker"] = "o" # marker type, see https://matplotlib.org/stable/api/markers_api.html for all options
# plt.rcParams["lines.color"] = "black" # color of the line
# # CHOOSE NICE COLOR FOR DARK MARKER EDGEWIDTH FROM "dodgerblue","mediumseagreen","crimson","mediumpurple","slateblue","darkorange","peru","goldenrod"

plt.rcParams["grid.linestyle"] = "--"
plt.rcParams['axes.grid'] = True
# plt.rcParams["grid.linewidth"] = 0.7

# plt.rcParams["xtick.major.pad"] = 4.0 # distance between xticks dashes and xaxis numbers
# plt.rcParams["xtick.major.size"] = 3.0
# plt.rcParams["xtick.major.width"] = 0.7
# plt.rcParams["ytick.major.pad"] = 4.0 # distance between yticks dashes and yaxis numbers
# plt.rcParams["ytick.major.size"] = 3.0
# plt.rcParams["ytick.major.width"] = 0.7





# plot two figures side by side
# fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, constrained_layout=True)
# plt.subplots_adjust(left=0.2, right=0.8, top=0.8, bottom=0.2) # remove unnecessary white space how i like it, this is manual very of use constrained_layout

# That warning is because matplotlib’s default layout engine has changed in recent
# versions to use constrained_layout, which is incompatible with subplots_adjust and tight_layout. 
# If you try to use plt.subplots_adjust when constrained_layout=True, matplotlib will raise that warning and ignore the call.
# If you're manually adjusting spacing, disable constrained_layout when you create the figure:

# %%
df = pd.read_csv("scope_8.csv", header=33) # data for scope 9 i.e. sidebands and transmisison peak and errorr signals
scope_eight_time = df.iloc[:, 0].values * 1000
scope_eight_trans = df.iloc[:, 1].values * 100 + 2.5
scope_eight_error = df.iloc[:, 2].values +0.0015 # convert to mV
scope_eight_error = scope_eight_error * 1000 + 50 # convert to mV

# %%
plt.plot(scope_eight_time, scope_eight_trans, label="Transmission Peaks", color="darkorange")
plt.plot(scope_eight_time, scope_eight_error, label="Error Signal", color="mediumseagreen")
plt.xlabel("Time (ms)")
plt.ylabel("Oscilloscope Voltage (mV)")
plt.legend(loc='upper left', bbox_to_anchor=(0.0, 0.5))

x_start = 0
x_end = 16
y_pos = 2.6

# # Draw double-headed arrow
# plt.annotate(
#     '', xy=(x_end, y_pos), xytext=(x_start, y_pos),
#     arrowprops=dict(arrowstyle='<->', color='black', lw=1.5)
# )
# # Place the label above the arrow
# plt.text(
#     (x_start + x_end) / 2, y_pos + 0.1, r'$\omega_{PDH}=5\,\mathrm{MHz}$',
#     ha='center', va='bottom', color='black'
# )

# %%
df2 = pd.read_csv("scope_32.csv",header=1) # data for scope 9 i.e. sidebands and transmisison peak and errorr signals
scope_thirty_two_time = df2.iloc[:, 0].values * 1e6
scope_thirty_two_trans = df2.iloc[:, 1].values * 250 + 9
scope_thirty_two_error = df2.iloc[:, 2].values - 0.065
scope_thirty_two_error = scope_thirty_two_error * 1000 / 3 + 50

# %%
plt.plot(scope_thirty_two_time-25, scope_thirty_two_trans, label="Transmission Peaks", color="darkorange")
plt.plot(scope_thirty_two_time-10, scope_thirty_two_error, label="Error Signal", color="mediumseagreen")
plt.xlabel(r"Time ($\mu$s)")
plt.ylabel("Oscilloscope Voltage (mV)")
plt.legend(loc='upper left', bbox_to_anchor=(0.0, 0.5))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True)

ax1.plot(scope_eight_time, scope_eight_trans, label="Transmission Peaks", color="darkorange")
ax1.plot(scope_eight_time, scope_eight_error, label="Error Signal", color="mediumseagreen")
ax1.set_xlabel("Time (ms)")
ax1.set_ylabel("Oscilloscope Voltage (mV)")
ax1.set_xticks([-20, -10, 0, 10, 20]) # set x ticks for the first plot
# ax1.legend(loc='upper left', bbox_to_anchor=(0.0, 0.5))

x_start = 0
x_end = 16
y_pos = 54

# Draw double-headed arrow
ax1.annotate(
    '', xy=(x_end, y_pos), xytext=(x_start, y_pos),
    arrowprops=dict(arrowstyle='<->', color='black', lw=1.5)
)
# Place the label above the arrow
ax1.text(
    (x_start + x_end) / 2, y_pos + 1.5, r'$\Omega$',
    ha='center', va='bottom', color='black'
)

ax2.plot(scope_thirty_two_time-25, scope_thirty_two_trans, label="Transmission Peaks", color="darkorange")
ax2.plot(scope_thirty_two_time-10, scope_thirty_two_error, label="Error Signal", color="mediumseagreen")
ax2.set_xlabel(r"Time ($\mu$s)")
# ax2.set_ylabel("Oscilloscope Voltage (mV)")
# ax2.legend(loc='upper left', bbox_to_anchor=(0.0, 0.5))

ax2.set_yticklabels([])
ax2.set_ylabel("")

ax1.set_ylim(-5, 70)
ax2.set_ylim(-5, 70)

plt.savefig("250604 PDHAllanDeviationCalibrationPlots.pdf", dpi=300)

# %%
plt.plot(scope_thirty_two_time-10, scope_thirty_two_error-50, label="Error Signal", color="mediumseagreen")

plt.ylabel("Oscilloscope Voltage (mV)")
plt.ylim(-25,15)
plt.xlabel(r"Time ($\mu$s)")
# plt.savefig('ErrorSignalPlot.pdf',dpi=300)
# Out:
# Text(0.5, 0, 'Time ($\\mu$s)')

# %%
plt.plot(scope_eight_time, scope_eight_error-50, label="Error Signal", color="mediumseagreen")
plt.ylabel("Oscilloscope Voltage (mV)")
plt.xlabel(r"Time (ms)")
# plt.savefig('ErrorSignalPlotWithSidebands.pdf',dpi=300)
# Out:
# Text(0.5, 0, 'Time (ms)')

# %% [markdown]
# # 250612 Compare with actual locking error signal (data in CSV)
#
# Data exported from 241201 PDHLockLongTermTraceThreeHours.ipynb, first 100 data points of error signal when locked, called zoomed_error_signal_edited_first100

# %%
df_locked_error_signal = pd.read_csv("zoomed_error_signal_edited_first100.csv", header=0)
df_locked_error_signal
# Out:
#     time_edited  error_signal_edited_mV
# 0         0.000                  1.7085
# 1         0.008                  8.9447
# 2         0.016                  7.3367
# 3         0.024                -15.9799
# 4         0.032                 11.3568
# ..          ...                     ...
# 95        0.760                  7.3367
# 96        0.768                -10.3518
# 97        0.776                -15.1759
# 98        0.784                 -7.9397
# 99        0.792                  5.7286
#
# [100 rows x 2 columns]

# %%
fig, (ax2, ax1) = plt.subplots(1, 2, constrained_layout=True)

ax1.plot(df_locked_error_signal.iloc[:, 0].values, df_locked_error_signal.iloc[:, 1].values-1, lw=1.25, label="Error Signal", color="mediumseagreen")
# ax1.set_ylabel('Error Signal (mV)')
ax1.set_xlabel('Time (s)')
ax1.axhspan(np.min(scope_thirty_two_error-50), np.max(scope_thirty_two_error-50), color='goldenrod', alpha=0.1, label='Locking Region')

ax2.plot(scope_thirty_two_time-10, (scope_thirty_two_error-50), label="Error Signal", color="mediumseagreen")
ax2.set_xlabel(r"Time ($\mu$s)")
ax2.set_ylabel("Oscilloscope Voltage (mV)")

ax2.axhline(np.max(scope_thirty_two_error-50), xmin=0.5, xmax=1, color='goldenrod', linestyle='dotted', linewidth=1.5)
ax2.axhline(np.min(scope_thirty_two_error-50), xmin=0.5, xmax=1, color='goldenrod', linestyle='dotted', linewidth=1.5)

ax1.set_ylim(-25,15)
ax2.set_ylim(-25,15)
ax1.set_yticks([-20,-10,0,10])
ax2.set_yticks([-20,-10,0,10])

# ax2.set_title("Calibration Scan")
# ax1.set_title("PDH Locked")

ax1.set_yticklabels([])
ax1.set_ylabel("")

# plt.savefig("250612 PDHErrorSignalComparisonCalibrationVsLocked.pdf", dpi=300)
# Out:
# Text(0, 0.5, '')

# %%
print(np.max(df_locked_error_signal['error_signal_edited_mV'])-np.min(df_locked_error_signal['error_signal_edited_mV']))
print(np.max(scope_thirty_two_error)-np.min(scope_thirty_two_error))
print((np.max(df_locked_error_signal['error_signal_edited_mV'])-np.min(df_locked_error_signal['error_signal_edited_mV']))/(np.max(scope_thirty_two_error)-np.min(scope_thirty_two_error)))
# Out:
# 29.7487
# 32.32830786666666
# 0.9202059112618615

# %% [markdown]
# # 250612 Compare with actual locking error signal (data in CSV)
#
# Data exported from 250614 PDHLockLongTermTraceThreeHours.ipynb, raw data 240419, middle 100 data points of error signal when locked, called errorsignal_slice_4900_5000

# %%
df_locked_error_signal = pd.read_csv("errorsignal_slice_4800_4900.csv", header=0)
df_locked_error_signal
# Out:
#     Time (s)  Error Signal (mV)
# 0      0.000             -4.788
# 1      0.008             -8.004
# 2      0.016            -12.024
# 3      0.024             -2.778
# 4      0.032              7.273
# ..       ...                ...
# 95     0.760            -10.416
# 96     0.768              0.036
# 97     0.776             -5.190
# 98     0.784            -10.416
# 99     0.792              7.273
#
# [100 rows x 2 columns]

# %%
fig, (ax2, ax1) = plt.subplots(1, 2, constrained_layout=True)

ax1.plot(df_locked_error_signal.iloc[:, 0].values, df_locked_error_signal.iloc[:, 1].values-1, lw=1.25, label="Error Signal", color="mediumseagreen")
# ax1.set_ylabel('Error Signal (mV)')
ax1.set_xlabel('Time (s)')
ax1.axhspan(np.min(scope_thirty_two_error-50), np.max(scope_thirty_two_error-50), color='goldenrod', alpha=0.1, label='Locking Region')

ax2.plot(scope_thirty_two_time-10, (scope_thirty_two_error-50), label="Error Signal", color="mediumseagreen")
ax2.set_xlabel(r"Time ($\mu$s)")
ax2.set_ylabel("Error Signal (mV)")

ax2.axhline(np.max(scope_thirty_two_error-50), xmin=0.5, xmax=1, color='goldenrod', linestyle='dotted', linewidth=1.5)
ax2.axhline(np.min(scope_thirty_two_error-50), xmin=0.5, xmax=1, color='goldenrod', linestyle='dotted', linewidth=1.5)

ax1.set_ylim(-25,15)
ax2.set_ylim(-25,15)
ax1.set_yticks([-20,-10,0,10])
ax2.set_yticks([-20,-10,0,10])

# ax2.set_title("Calibration Scan")
# ax1.set_title("PDH Locked")

ax1.set_yticklabels([])
ax1.set_ylabel("")

plt.savefig("250614 PDHErrorSignalComparisonCalibrationVsLocked.pdf", dpi=300)

# %%
print(np.max(df_locked_error_signal.iloc[:,1].values)-np.min(df_locked_error_signal.iloc[:,1].values))
print(np.max(scope_thirty_two_error)-np.min(scope_thirty_two_error))
print((np.max(df_locked_error_signal.iloc[:,1].values)-np.min(df_locked_error_signal.iloc[:,1].values))/(np.max(scope_thirty_two_error)-np.min(scope_thirty_two_error)))
# Out:
# 22.110999999999997
# 32.32830786666666
# 0.6839516652462466
