# %%
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(['science','ieee','no-latex'])

# %%
plt.figure(figsize=(6,4))
plt.plot([1,2,3],[4,5,6])
plt.ylabel('Some Numbers')
plt.xlabel('Hello')
plt.title('Sup sup hello there')
plt.show()
