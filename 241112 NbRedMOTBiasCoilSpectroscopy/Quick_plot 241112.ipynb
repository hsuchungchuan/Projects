# %%
from mot_analysis.motimg import MOTImaging
# blue mot tof flight measurement
import os
import glob
import h5py
import json
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
## WINDOWS: On your .ipynb, import this plotting_style by adding in and uncommenting the following lines:
import matplotlib.pyplot as plt
import sys
sys.path.append('C:/Users/Michael/Dropbox/AION/Projects')  # Replace with the relevant path that contains this script
from plotting_style import set_plotting_style
set_plotting_style()

## MAC: On your .ipynb, import this plotting_style by adding in and uncommenting the following lines:
# import matplotlib.pyplot as plt
# import sys
# sys.path.append('/Users/michael/Dropbox/AION/Projects')  # Replace with the relevant path that contains this script
# from plotting_style import set_plotting_style
# set_plotting_style()


import matplotlib.pyplot as plt

print('Initialising plotting style...')

def set_plotting_style():
    plt.rc("font", family = 'Arial', size=10)
    plt.rc('axes', labelsize=20, titlesize = 20, labelpad=5)
    plt.rc('xtick', labelsize=18)
    plt.rc('ytick', labelsize=18)
    plt.rc('legend', fontsize=15)

print('Success! Plotting style initialised.')
# Out:
# Initialising plotting style...
# Success! Plotting style initialised.

# %% [markdown]
# # Import and quick plot

# %%
# file name and path
file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial2A\000016846-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_2A = h5file['datasets/ndscan.rid_16846.points.axis_0'][:]
    y_2A = h5file['datasets/ndscan.rid_16846.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x_2A = np.delete(x_2A, 0)
y_2A = np.delete(y_2A, 0)
x_2A = np.delete(x_2A, 2)
y_2A = np.delete(y_2A, 2)

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial1A\000016845-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_1A = h5file['datasets/ndscan.rid_16845.points.axis_0'][:]
    y_1A = h5file['datasets/ndscan.rid_16845.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x_1A = np.delete(x_1A, 3)
y_1A = np.delete(y_1A, 3)
x_1A = np.delete(x_1A, 13)
y_1A = np.delete(y_1A, 13)

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial5Afine\000016843-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_5A = h5file['datasets/ndscan.rid_16843.points.axis_0'][:]
    y_5A = h5file['datasets/ndscan.rid_16843.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial3A\000016844-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_3A = h5file['datasets/ndscan.rid_16844.points.axis_0'][:]
    y_3A = h5file['datasets/ndscan.rid_16844.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_AllBias0A\000016839-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_0A = h5file['datasets/ndscan.rid_16839.points.axis_0'][:]
    y_0A = h5file['datasets/ndscan.rid_16839.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]



file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial2pt5A\000016841-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_2pt5A = h5file['datasets/ndscan.rid_16841.points.axis_0'][:]
    y_2pt5A = h5file['datasets/ndscan.rid_16841.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x_2pt5A = np.delete(x_2pt5A, 1)
y_2pt5A = np.delete(y_2pt5A, 1)

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial0pt5A\000016847-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_0pt5A = h5file['datasets/ndscan.rid_16847.points.axis_0'][:]
    y_0pt5A = h5file['datasets/ndscan.rid_16847.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

x_0pt5A = np.delete(x_0pt5A, 12)
y_0pt5A = np.delete(y_0pt5A, 12)

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_AllBias0A\000016839-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_0A = h5file['datasets/ndscan.rid_16839.points.axis_0'][:]
    y_0A = h5file['datasets/ndscan.rid_16839.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial0pt1A\000016848-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_0pt1A = h5file['datasets/ndscan.rid_16848.points.axis_0'][:]
    y_0pt1A = h5file['datasets/ndscan.rid_16848.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial0pt3A\000016849-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_0pt3A = h5file['datasets/ndscan.rid_16849.points.axis_0'][:]
    y_0pt3A = h5file['datasets/ndscan.rid_16849.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial-0pt5A\000016850-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_minus0pt5A = h5file['datasets/ndscan.rid_16850.points.axis_0'][:]
    y_minus0pt5A = h5file['datasets/ndscan.rid_16850.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

file_path = r"Z:\AION\Data\2024\11\12\nbMOT_Axial-1A\000016851-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_minus1A = h5file['datasets/ndscan.rid_16851.points.axis_0'][:]
    y_minus1A = h5file['datasets/ndscan.rid_16851.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

# Plotting the data#
plt.figure(figsize=(12, 10))

plt.plot(x_minus1A/1e6, y_minus1A/10, '.-', markersize=18, linewidth=2,label='-1.0A')
plt.plot(x_minus0pt5A/1e6, y_minus0pt5A/10, '.-', markersize=18, linewidth=2,label='-0.5A')
plt.plot(x_0A/1e6, y_0A/10, '^-', markersize=18, linewidth=2,label='0A')
plt.plot(x_0pt1A/1e6, y_0pt1A/10, '.-', markersize=18, linewidth=2,label='0.1A')
plt.plot(x_0pt3A/1e6, y_0pt3A/10, '.-', markersize=18, linewidth=2,label='0.3A')
plt.plot(x_0pt5A/1e6, y_0pt5A/10, '.-', markersize=18, linewidth=2,label='0.5A')
plt.plot(x_1A/1e6, y_1A/10, '.-', markersize=18, linewidth=2,label='1A')
plt.plot(x_2A/1e6, y_2A/10, '.-', markersize=18, linewidth=2,label='2A')
plt.plot(x_2pt5A/1e6, y_2pt5A/10, '.-', markersize=18, linewidth=2,label='2.5A')
plt.plot(x_3A/1e6, y_3A/10, '.-', markersize=18, linewidth=2,label='3A')
plt.plot(x_5A/1e6, y_5A/10, '.-', markersize=18, linewidth=2,label='5A')



# plt.title('nb red mot 0A normalized pixel sum vs dpaom frequency\n mirny 460MHz mod width 10MHz +2.0A for axial', fontsize=20, pad=20)
# Increase tick label size
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Red DPAOM frequency (MHz)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.legend(fontsize=20)
ax2 = plt.twiny()
frequencyoffsetfromcavity = x_2A/1e6 *2 + 460 - 100
ax2.plot(frequencyoffsetfromcavity, y_2A/10, 'o-', alpha=0)  # Large dots and connected points
ax2.set_xlabel('Frequency offset from cavity (MHz)', fontsize=20, labelpad=12)
ax2.tick_params(axis='x', which='major', labelsize=20)

plt.title('Narrowband red MOT spectroscopy for different axial bias coil currents', fontsize=25, pad=12)

#plt.xlim(340, 360)
# plt.ylim(-0.05,0.95)
plt.grid(True)
# Adjust layout to prevent cut off
plt.tight_layout()
# Save the plot with 300 DPI
plt.savefig('241112 Narrowband red MOT spectroscopy for different axial bias coil current.pdf', dpi=1200)

plt.show()
