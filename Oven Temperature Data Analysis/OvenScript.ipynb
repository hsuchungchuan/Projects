# %%
# extract excel data in the same folder

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# read excel file
df = pd.read_excel('Oven-data-as-joinbyfield-2023-07-07 12_38_18.xlsx', sheet_name='Oven-data-as-joinbyfield-2023-0')

# %%
df
# Out:
#                      Time         Time.1  picolog.HeaterTemperature  \
# 0     2023-06-07 12:37:00  1686137820000                 342.040142
# 1     2023-06-07 12:38:00  1686137880000                 342.206417
# 2     2023-06-07 12:39:00  1686137940000                 342.356679
# 3     2023-06-07 12:40:00  1686138000000                 342.505633
# 4     2023-06-07 12:41:00  1686138060000                 342.654357
# ...                   ...            ...                        ...
# 43191 2023-07-07 12:28:00  1688729280000                 420.350403
# 43192 2023-07-07 12:29:00  1688729340000                 421.358795
# 43193 2023-07-07 12:30:00  1688729400000                 422.331268
# 43194 2023-07-07 12:31:00  1688729460000                 423.239504
# 43195 2023-07-07 12:32:00  1688729520000                 424.411774
#
#        picolog.LowerFlangePosition  picolog.OvenBaseTemperature  \
# 0                        21.830665                   261.246767
# ...

# %%
#plot time series data for picolog.OvenBaseTemperature

# df.plot(x='Time', y='picolog.OvenBaseTemperature', figsize=(20,10), grid=True)

#plot x axis as datetime and show all dates

df['Time'] = pd.to_datetime(df['Time'])
df.plot(x='Time', y='picolog.OvenBaseTemperature', figsize=(20,10), grid=True, x_compat=True)

#rotate x axis labels to 90 degrees

plt.xticks(rotation=90)
# Out:
# (array([19517., 19521., 19525., 19529., 19533., 19537., 19539., 19543.,
#         19547.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
