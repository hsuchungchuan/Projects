# %%
from mot_analysis.motimg import MOTImaging
# blue mot tof flight measurement
import os
import glob
import h5py
import json
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
## WINDOWS: On your .ipynb, import this plotting_style by adding in and uncommenting the following lines:
import matplotlib.pyplot as plt
import sys
sys.path.append('C:/Users/Michael/Dropbox/AION/Projects')  # Replace with the relevant path that contains this script
from plotting_style import set_plotting_style
set_plotting_style()

## MAC: On your .ipynb, import this plotting_style by adding in and uncommenting the following lines:
# import matplotlib.pyplot as plt
# import sys
# sys.path.append('/Users/michael/Dropbox/AION/Projects')  # Replace with the relevant path that contains this script
# from plotting_style import set_plotting_style
# set_plotting_style()


import matplotlib.pyplot as plt

print('Initialising plotting style...')

def set_plotting_style():
    plt.rc("font", family = 'Arial', size=10)
    plt.rc('axes', labelsize=20, titlesize = 20, labelpad=5)
    plt.rc('xtick', labelsize=18)
    plt.rc('ytick', labelsize=18)
    plt.rc('legend', fontsize=15)

print('Success! Plotting style initialised.')
# Out:
# Initialising plotting style...
# Success! Plotting style initialised.
# Initialising plotting style...
# Success! Plotting style initialised.

# %% [markdown]
# # Import and quick plot

# %%
file_path = r"Z:\AION\Data\2024\12\03\mike_yj_redmot_opt_ndscan\000017790-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_data = h5file['datasets/ndscan.rid_17790.points.axis_0'][:]
    y_data = h5file['datasets/ndscan.rid_17790.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

plt.figure(figsize=(8, 6))
plt.plot(x_data, y_data/10,'o-', markersize=18, linewidth=2)

# %%
file_path = r"Z:\AION\Data\2024\12\03\mike_yj_redmot_opt_ndscan\000017785-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_data = h5file['datasets/ndscan.rid_17785.points.axis_0'][:]
    y_data = h5file['datasets/ndscan.rid_17785.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

plt.figure(figsize=(8, 6))
plt.plot(x_data*1e3, y_data/10,'o-', markersize=18, linewidth=2)
plt.xlabel('Blue ramping duration (ms)',fontsize=20)
plt.ylabel('Normalized horizontal pixel sum',fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Broadband red MOT for different \n blue ramping durations (30ms per step)',fontsize=20,pad=10)
plt.xticks(np.linspace(0, 500, 11))
plt.xlim(0, 350)
plt.grid(True)
plt.tight_layout()
plt.savefig('Broadband red MOT for different blue ramping durations 30ms per step.pdf', dpi=1200)

# %%
file_path = r"Z:\AION\Data\2024\12\03\mike_yj_redmot_opt_ndscan\000017786-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_data = h5file['datasets/ndscan.rid_17786.points.axis_0'][:]
    y_data = h5file['datasets/ndscan.rid_17786.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

plt.figure(figsize=(8, 6))
plt.plot(x_data*1e3, y_data/10,'o-', markersize=18, linewidth=2)
plt.xlabel('Blue ramping duration (ms)',fontsize=20)
plt.ylabel('Normalized horizontal pixel sum',fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Broadband red MOT for different \n blue ramping durations (20ms per step)',fontsize=20,pad=10)
plt.xticks(np.linspace(0, 250, 11))
plt.yticks(np.linspace(0, 0.2, 6))
plt.xlim(0,240)
plt.ylim(0,0.16)
plt.grid(True)
plt.tight_layout()
plt.savefig('Broadband red MOT for different blue ramping durations 20ms per step.pdf', dpi=1200)

# %%
file_path = r"Z:\AION\Data\2024\12\03\mike_yj_redmot_opt_ndscan\000017788-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_data = h5file['datasets/ndscan.rid_17788.points.axis_0'][:]
    y_data = h5file['datasets/ndscan.rid_17788.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

plt.figure(figsize=(8, 6))
plt.plot(x_data*1e3, y_data/10,'o-', markersize=18, linewidth=2)
plt.xlabel('Blue ramping duration (ms)',fontsize=20)
plt.ylabel('Normalized horizontal pixel sum',fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Broadband red MOT for different \n blue ramping durations (10ms per step)',fontsize=20,pad=10)
plt.xticks(np.linspace(0, 200, 11))
plt.xlim(0,210)
plt.grid(True)
plt.tight_layout()
plt.savefig('Broadband red MOT for different blue ramping durations 10ms per step.pdf', dpi=1200)

# %%
# file name and path
file_path = r"Z:\AION\Data\2024\12\03\mike_yj_redmot_opt_ndscan\000017790-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x = h5file['datasets/ndscan.rid_17790.points.axis_0'][:]
    y = h5file['datasets/ndscan.rid_17790.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

# Plotting the data#
plt.figure(figsize=(8, 6))
plt.plot(x, y/10, 'o-', markersize = 20)  # Large dots and connected points
plt.tick_params(axis='both', which='major', labelsize=20)
# plt.xticks(np.arange(0, 1.1, 0.1))
plt.xlabel('Broadband red MOT duration (s)', fontsize=20)
plt.ylabel('Normalized horizontal pixel sum', fontsize=20)
plt.title('Broadband red MOT hold duration', fontsize=25, pad=12)
plt.grid(True)
plt.tight_layout()
plt.savefig('241203 Broadband red MOT I hold duration.pdf', dpi=1200)

# %%
file_path = r"Z:\AION\Data\2024\12\03\mike_yj_redmot_opt_ndscan\000017792-MeasureRedMOT.h5"
# Open the HDF5 file to extract the relevant datasets
with h5py.File(file_path, 'r') as h5file:
    # Extracting the axis and data for plotting
    x_data = h5file['datasets/ndscan.rid_17792.points.axis_0'][:]
    y_data = h5file['datasets/ndscan.rid_17792.points.channel_red_mot_normalised_bg_corrected_img_sum_horiz'][:]

plt.figure(figsize=(10, 6))
plt.plot(x_data, y_data/10,'o-', markersize=18, linewidth=2)
plt.xlabel('Low power supply current (A)',fontsize=20)
plt.ylabel('Normalized horizontal pixel sum',fontsize=20)
plt.xticks(np.linspace(0, 20, 11))
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Broadband red MOT for different magnetic fields or currents',fontsize=20,pad=10)
plt.grid(True)

magnetic_field = [i*0.388 for i in x_data]
ax2 = plt.twiny()
ax2.plot(magnetic_field, y_data/10, alpha=0)
ax2.set_xlabel('Magnetic field (G/cm)',fontsize=20,labelpad=10)

plt.tight_layout()
plt.savefig('241203 Broadband red MOT for different magnetic fields.pdf', dpi=1200)
