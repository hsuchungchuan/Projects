# %%
import pandas as pd

import matplotlib.pyplot as plt

for i in range(22, 29):
    filename = f'scope_{i}.csv'
    df = pd.read_csv(filename, header=1)
    plt.figure()
    df.plot(x='second', y='Volt.1')
    # # Find the index closest to time=0
    # zero_idx = (df['second'] - 0).abs().idxmin()
    # # Select +-500 indices around zero_idx, ensuring bounds are within the dataframe
    # start_idx = max(zero_idx - 500, 0)
    # end_idx = min(zero_idx + 500, len(df) - 1)
    # df_zoom = df.iloc[start_idx:end_idx+1]
    # df_zoom.plot(x='second', y='Volt.1')
    plt.title(f'Data from {filename}')
    plt.xlabel('Time (s)')
    plt.ylabel('Voltage (V)')
    plt.show()
